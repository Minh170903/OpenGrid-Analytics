# %% [markdown]
# # **Data Acquisition**

# %% [markdown]
# **Setting up environment**

# %%
# Set your API key
# %env OPENELECTRICITY_API_KEY=oe_3ZPqjof54kKpHxcpFqkpmYht
# Out:
# env: OPENELECTRICITY_API_KEY=oe_3ZPqjof54kKpHxcpFqkpmYht

# %%
import os, time, math, requests
from datetime import datetime, timezone
import os, csv, requests
from collections import defaultdict

# %% [markdown]
# ## **Retrieve all facility code**

# %% [markdown]
# **API call to get all unique facility and unit code**

# %%
API = "https://api.openelectricity.org.au"
TOKEN = os.environ.get("OPENELECTRICITY_API_KEY") or "oe_3ZVkmJvbjLU4yPJCHaZXhBgS"
H = {"Authorization": f"Bearer {TOKEN}", "Accept":"application/json"}

def get(url, params):
    r = requests.get(url, headers=H, params=params, timeout=60)
    r.raise_for_status()
    return r.json()


# Power + emissions by region
resp2 = get(f"{API}/v4/facilities/", {
    'network_id': 'NEM',
    'status_id': 'operating'
})

# %% [markdown]
# **flatten the retrieved data to a normalised pandas dataframe**

# %%
import pandas as pd

# Flatten to "one row per UNIT", while carrying facility metadata down via `meta`
units_flat = pd.json_normalize(
    resp2["data"],
    record_path="units",
    meta=[
        "code", "name", "network_id", "network_region",
        "description", "updated_at", "created_at",
        ["location", "lat"], ["location", "lng"]
    ],
    meta_prefix="facility_",       # avoid name clashes with unit fields
    errors="ignore"
)

# Rename columns
facilities_df = (
    units_flat
      .rename(columns={
          "code": "unit_code",                  # unit code -> subfacility
          "dispatch_type": "dispatch_type",
          "facility_code": "facility_code",
          "facility_name": "name",
          "facility_network_id": "network_id",
          "facility_network_region": "network_region",
          "facility_description": "description",
          "facility_updated_at": "updated_at",
          "facility_created_at": "created_at",
          "facility_location.lat": "lat",
          "facility_location.lng": "lng",
      })
      # Reorder
      .loc[:, [
          "facility_code", "unit_code", "dispatch_type", "fueltech_id",
          "name", "network_id", "network_region", "lat", "lng"
      ]]
)

# make lat/lng numeric
facilities_df["lat"] = pd.to_numeric(facilities_df["lat"], errors="coerce")
facilities_df["lng"] = pd.to_numeric(facilities_df["lng"], errors="coerce")

facilities_df
# Out:
#     facility_code unit_code  dispatch_type          fueltech_id  \
# 0             ADP    ADPBA1  BIDIRECTIONAL              battery
# 1             ADP   ADPBA1G      GENERATOR  battery_discharging
# 2             ADP   ADPBA1L           LOAD     battery_charging
# 3             ADP    ADPPV1      GENERATOR        solar_utility
# 4             ADP    ADPPV2      GENERATOR        solar_utility
# ..            ...       ...            ...                  ...
# 639      YWNGAHYD  YWNGAHYD      GENERATOR                hydro
# 640        YARWUN  YARWUN_1      GENERATOR             gas_ccgt
# 641        YATSF1    YATSF1      GENERATOR        solar_utility
# 642         YAWWF    YAWWF1      GENERATOR                 wind
# 643      YENDONWF   YENDWF1      GENERATOR                 wind
#
#                       name network_id network_region        lat         lng
# 0    Adelaide Desalination        NEM            SA1 -35.096948  138.484061
# 1    Adelaide Desalination        NEM            SA1 -35.096948  138.484061
# 2    Adelaide Desalination        NEM            SA1 -35.096948  138.484061
# 3    Adelaide Desalination        NEM            SA1 -35.096948  138.484061
# 4    Adelaide Desalination        NEM            SA1 -35.096948  138.484061
# ..                     ...        ...            ...        ...         ...
# 639             Yarrawonga        NEM           VIC1 -36.009466  145.999568
# 640                 Yarwun        NEM           QLD1 -23.830200  151.149692
# 641                Yatpool        NEM           VIC1 -34.380730  142.205340
# 642                 Yawong        NEM           VIC1 -36.471022  143.361722
# 643                 Yendon        NEM           VIC1 -37.630952  144.022463
#
# [644 rows x 9 columns]

# %%
#store facility code in an array
unique_facility_codes = facilities_df['facility_code'].unique()
unique_facility_codes
# Out:
# array(['ADP', 'ALDGASF', 'ANGASTON', 'APPIN', 'ARWF', 'AVLSF', 'DEIBDL',
#        'BAKING', 'BHWF', 'BALBESS', 'BANGOWF', 'BAPS', 'BANNSP',
#        'BARCALDN', 'BARCSF', 'BARKIPS', 'BARRON', 'BASTYAN', 'BAYSW',
#        'BBP31', 'BRYB1WF1', 'BERWICK', 'BERYLSF', 'BIALAWF', 'BLAYNEY',
#        'SNOWY6', 'BLUEGSF', 'BLYTHB', 'BOCOROCK', 'BODWF', 'MCKAY',
#        'BOLIVAR', 'BOLIVPS', 'BOMENSF', 'BBATTERY', 'BRAEMARA', 'B2PS',
#        'BRNDBES', 'BWTR1', 'BHILLGT', 'BROKENH', 'BHB', 'BROOKLYN',
#        'BROWNMT', 'BPLANDF', 'BULGANA', 'BNGSF1', 'BNGSF2', 'BDONGHYD',
#        'BURRIN', 'BUTLERSG', 'CALL_B', 'CALLIDEC1', 'CANUNDA1', 'CAPBES',
#        'CAPTL_WF', 'CESF', 'LI_WY_CA', 'CATHROCK', 'CTHLWF', 'CETHANA',
#        'CHALLWF', 'CHPSTWF', 'CHYTWF', 'CHILDSF', 'CHBESS', 'CBWWBA',
#        'CLARESF', 'CLRKCWF', 'CLAYTON', 'CLEMGPWF', 'CLERMSF', 'CLOVER',
#        'CLUNY', 'CODRGTON', 'COHUNSF1', 'COLEASF', 'COLWF01', 'CSPVPS',
#        'COLONGRA', 'COLUMSF', 'CPSA', 'CONDONG1', 'CBWF', 'COOPGWF',
#        'COPTNHYD', 'CRWASF1', 'CROOKWEL', 'CROOKWF2', 'CROOKWF3',
#        'CROWLWF', 'CRURWF1', 'CULCSF', 'CULLERIN', 'DALNTH', 'DDPS1',
#        'DDSF', 'DARLSF', 'DPNTB', 'DARTM', 'DAYDSF', 'DEVILS_G',
#        'DIAPURWF', 'DRYCGT', 'DULAWF', 'DUNDWF', 'EASTCRK', 'EASTCRK2',
#        'EDENVSF', 'EILDON', 'EILDONPD', 'ELAINEWF', 'EMERASF', 'ERARING',
#        'ERB', 'ERGT01', 'FWF', 'FINLEYSF', 'FISHER', 'FLYCRKWF',
#        'GANGARR', 'GANNBESS', 'GANNSF', 'GERMCRK', 'GIRGSF', 'GSTONE',
#        'GLBWNHYD', 'GESF', 'GLENMAGG', 'GLENNCRK', 'GLENSF', 'GLRWNSF',
#        'GPWFEST', 'GOONUMSF', 'GOESF1', 'GORDON', 'GSWF', 'GRANGEAV',
#        'GRANWF', 'GREENB', 'GRIFSF', 'GROSV1', 'GROSV2', 'GULLRGWF',
#        'GNNDHSF', 'GUNNING', 'GUSF', 'SNOWY3', 'HLMSEW01', 'HALAMRD',
#        'AGLHAL', 'HALLWF', 'HALLWF2', 'HAMISF', 'HAMPTON', 'HVWW',
#        'HASTING', 'HAUGHT1', 'HD1WF', 'HAYMSF', 'HBESS', 'HEPWIND',
#        'HILLSTN', 'HORNSDAL', 'HORNSDAL2', 'HORNSDAL3', 'HORNSDPR',
#        'HUGSF', 'HUMENSW', 'HUMEV', 'HUNTER', 'HEZ', 'INVICTA', 'ICSM',
#        'JACKSGUL', 'JEERA', 'JEERB', 'JEMALNG1', 'JNDSHPS', 'SNWYGJP2',
#        'JBUTTERS', 'JOUNAMA', 'JUNEESF', 'KABANWF', 'KARSF', 'KAREEYA',
#        'KEEPIT', 'AGLSITA', 'KENNEDY', 'KERNGSP', 'KIAMSF1', 'KIATAWF',
#        'KSP1', 'KINGASF', 'KOGANCK', 'KESS1', 'LADBROKE', 'LBBESS',
#        'LKBONNY1', 'LKBONNY_2', 'LKBONNY3', 'LK_ECHO', 'LVES', 'LNGS',
#        'LEM_WIL', 'LILYVASF', 'LIMBESS', 'LIMOSF1', 'LIMOSF2', 'LGAPWF1',
#        'LONGFORD', 'LRSF', 'LONSDALE', 'LOYYANGA', 'LOYYB', 'LUCASHGT',
#        'LUCAS2S2', 'MACARTH', 'MCINTYR', 'MACKAY', 'MACKNTSH', 'MANSLR',
#        'MANNUMB', 'MANNSF', 'MAPS2', 'MAROOWF1', 'MARYRSF', 'MEADOWBK',
#        '0MREH', '0MREHA2', 'MREHA3', 'METZSF', 'MIDDLSF1', 'MIDLDPS',
#        'MILLMERN', 'MINTARO', 'MOKOSF', 'MOLNGSF1', 'MOORAWF1',
#        'MORANBAH', 'MBAHNTH', 'MOREESF', 'MWPS', 'MORTLK', 'MRTLSWF',
#        'MLWF', 'MOUSF', 'MEWF', 'MTGELWF', 'MTMERCER', 'MTMILLAR', 'MP',
#        'MSTUART', 'MLSP', 'MUCRKSF', 'MUWAWF', 'MURRAY', 'MBPS2',
#        'MUSSELRO', 'NASF', 'NEVERSF', 'NEWENSF', 'NEWPORT', 'NBHWF',
#        'NUMURKSF', 'NYNGAN', 'OAKEY', 'OAKEY2SF', 'OAKEY1SF', 'OAKLAND',
#        'OCPS', 'OAKY2', 'OSBORNE', 'PALOONA', 'PSF', 'NPPPPS', 'PIBESS',
#        'PINDARI', 'PIONEER', 'PTINA', 'PAREPW', 'PORTLCN', 'STANVAC',
#        'PORTWF', 'QUARANTN', 'QBYNB', 'RACOMIL', 'RANGEB', 'REECE',
#        'REPULSE', 'RESS', 'RIVNB', 'RPCG', 'ROMA', 'RRSF', 'ROWALLAN',
#        'ROYALLA', 'RUBICON', 'RUGBYR', 'RYANCWF', 'RYEPARK', 'SALTCRK',
#        'SAPHWF1', 'SEBSF', 'SHEP1', 'SHOALHAV', 'SHOAL', 'STWF', 'SITHE',
#        'SMTHBES1', 'SNAPPER', 'SNOWTOWN', 'SNOWNTH', 'SNOWSTH', 'SNUG',
#        'AGLSOM', 'SKSF', 'STGEORGE', 'STANWELL', 'STAPYLTON', 'STARFHILL',
#        'STOCKYD', 'STUBSF', 'SMCSF', 'SUNRSF1', 'VALDORA', 'SUNTPSF',
#        'SNB1', 'SRSF', 'SWANBBF', 'SWAN_E', 'TABMILL2', 'TAHMOOR', 'TBSF',
#        'TB2SF', 'TALLAWAR', 'TALWB', 'TVCCPS', 'TARALGA', 'TARBESS',
#        'TARONG', 'TARONGN', 'TARRALEA', 'TATIARA', 'TATURA', 'TEMPB',
#        'BLUFF', 'THEDROP', 'TIMWEST', 'TOORAWF', 'TIB', 'TORRIS', 'TOWER',
#        'YABULU', 'TGNSS', 'TREVALLN', 'TRIBUTE', 'TULLYSM', 'SNOWY2',
#        'TUMUT3', 'TUNGATIN', 'ULBESS', 'URANQ', 'VP', 'VPGS', 'TITREE',
#        'VICMILL', 'VBB', 'WAGGNSF', 'WLWLSF', 'WALGRV', 'PRDSO_WALPOLE',
#        '0WAMBOWF', 'WANDSF', 'WANDBG', 'WNSF', 'WTAHB', 'WARWSF',
#        'WATERLWF', 'WPWF', 'WAUBRAWF', 'WELLSF1', 'WELNSF', 'WEMENSF1',
#        'WESTILLA', 'WKIEWA', 'WSTWYSF', 'WDBESS', 'WDGPH', 'WDBESS2',
#        'WRSF1', 'WRWF1', 'WHITSF', 'WHIT1', 'WILGAPK', 'WILGAPKB',
#        'WILLHOV', 'WGWF', 'WINDHILL', 'WINGF1', 'WINGF2', 'WINTSF1',
#        'WIVENHOE', 'WOLARSF', 'WOLLERT', 'WONWP', 'WDLNGN', 'WOODLWN',
#        'WOOLNTH1', 'WOOLGSF', 'WUNUSF', 'WYASF', 'WYANGALA', 'WYANGALB',
#        'YALLOURN', 'YSWF', 'YAMBUK', 'YARANSF', 'YWNGAHYD', 'YARWUN',
#        'YATSF1', 'YAWWF', 'YENDONWF'], dtype=object)

# %% [markdown]
# ## **Retrieve data (metrics) for all facilities**

# %% [markdown]
# Now since we have all the facility code, we can make another series of API call to retrieve all the required metrics. But here, it gets tricky as we can only retrieve data for at most 10 facilities per time, else we get a "bad request" warning. So to tackle this, I will implement a loop that makes 50 API calls with a delay of 0.6 seconds between each call to respect the API :)))

# %% [markdown]
# ### **Retrieving Facility metrics in batch (10 per batch)**

# %%
import time
import pandas as pd

BATCH_SIZE = 10
SLEEP_SEC  = 0.6     # small pause between calls
DATE_START = "2025-10-07T00:00:00"  # NEM time, timezone-naive
DATE_END   = "2025-10-14T00:00:00"  # exclusive
STEP_HOURS = 5/60  # 5-minute interval
cells = {}

for i in range(0, len(unique_facility_codes), BATCH_SIZE):
    batch = unique_facility_codes[i:i+BATCH_SIZE]

    resp = get(f"{API}/v4/data/facilities/NEM", {
        "facility_code": batch,
        "metrics": ["power", "emissions"],
        "interval": "5m",
        "date_start": DATE_START,
        "date_end": DATE_END
    })

    for block in resp.get("data", []):
        metric = block.get("metric")  # "power" or "emissions"
        for series in block.get("results", []):
            cols = series.get("columns") or {}
            unit_code = cols.get("unit_code")

            if not unit_code:
                # fallback: try parse from name like "power_MP1"
                name = series.get("name", "")
                unit_code = name.split("_")[-1] if "_" in name else None
            if not unit_code:
                continue

            for ts, val in series.get("data", []):
                key = (unit_code, ts)
                row = cells.setdefault(key, {"unit_code": unit_code, "ts": ts})
                row[metric] = val

    time.sleep(SLEEP_SEC)  # be polite to the API

# build the single dataframe for all 500 facilities
df = pd.DataFrame(list(cells.values()))

# dtypes
df["ts"] = pd.to_datetime(df["ts"], utc=True, errors="coerce")
for c in ["power", "emissions"]:
    if c in df.columns:
        df[c] = pd.to_numeric(df[c], errors="coerce")

# add facility_code from units_flat mapping
unit_to_facility = dict(zip(units_flat["code"], units_flat["facility_code"]))
df["facility_code"] = df["unit_code"].map(unit_to_facility)

# tidy columns
want_cols = ["facility_code", "unit_code", "ts", "power", "emissions"]
for col in want_cols:
    if col not in df.columns:
        df[col] = pd.NA

df = (
    df[want_cols]
    .sort_values(["facility_code", "unit_code", "ts"])
    .reset_index(drop=True)
)

print(df.shape)
df.head()
# Out:
# (985459, 5)
#   facility_code unit_code                        ts   power  emissions
# 0         0MREH    MREHA1 2025-10-06 14:00:00+00:00 -3.3805        0.0
# 1         0MREH    MREHA1 2025-10-06 14:05:00+00:00  0.9567        0.0
# 2         0MREH    MREHA1 2025-10-06 14:10:00+00:00 -1.9638        0.0
# 3         0MREH    MREHA1 2025-10-06 14:15:00+00:00  0.5740        0.0
# 4         0MREH    MREHA1 2025-10-06 14:20:00+00:00 -1.9504        0.0

# %% [markdown]
# **Save to csv files to avoid susequent APi call**

# %%
# Save the DataFrame to a CSV file
df.to_csv("facilities_metrics.csv", index=False)

facilities_df.to_csv("facilities_data.csv", index=False)

# %% [markdown]
# ## **Now we import the data and perform some cleaning**

# %%
import pandas as pd

# Import the CSV files into DataFrames
df = pd.read_csv("facilities_metrics.csv")
facilities_df = pd.read_csv("facilities_data.csv")

# %% [markdown]
# **Merge facility metric and facility data**

# %%
# Merge df and facilities_df on facility_code and unit_code
merged_df = pd.merge(df, facilities_df, on=['facility_code', 'unit_code'], how='left')

print("Merged DataFrame:")
merged_df.head()
# Out:
# Merged DataFrame:
#   facility_code unit_code                         ts   power  emissions  \
# 0         0MREH    MREHA1  2025-10-06 14:00:00+00:00 -3.3805        0.0
# 1         0MREH    MREHA1  2025-10-06 14:05:00+00:00  0.9567        0.0
# 2         0MREH    MREHA1  2025-10-06 14:10:00+00:00 -1.9638        0.0
# 3         0MREH    MREHA1  2025-10-06 14:15:00+00:00  0.5740        0.0
# 4         0MREH    MREHA1  2025-10-06 14:20:00+00:00 -1.9504        0.0
#
#    dispatch_type fueltech_id          name network_id network_region  \
# 0  BIDIRECTIONAL     battery  Melbourne A1        NEM           VIC1
# 1  BIDIRECTIONAL     battery  Melbourne A1        NEM           VIC1
# 2  BIDIRECTIONAL     battery  Melbourne A1        NEM           VIC1
# 3  BIDIRECTIONAL     battery  Melbourne A1        NEM           VIC1
# 4  BIDIRECTIONAL     battery  Melbourne A1        NEM           VIC1
#
#          lat         lng
# 0 -37.661274  144.726302
# 1 -37.661274  144.726302
# 2 -37.661274  144.726302
# 3 -37.661274  144.726302
# 4 -37.661274  144.726302

# %%
merged_df
# Out:
#        facility_code unit_code                         ts   power  emissions  \
# 0              0MREH    MREHA1  2025-10-06 14:00:00+00:00 -3.3805        0.0
# 1              0MREH    MREHA1  2025-10-06 14:05:00+00:00  0.9567        0.0
# 2              0MREH    MREHA1  2025-10-06 14:10:00+00:00 -1.9638        0.0
# 3              0MREH    MREHA1  2025-10-06 14:15:00+00:00  0.5740        0.0
# 4              0MREH    MREHA1  2025-10-06 14:20:00+00:00 -1.9504        0.0
# ...              ...       ...                        ...     ...        ...
# 989486           NaN   HUNTER2  2025-10-13 13:35:00+00:00  0.0000        0.0
# 989487           NaN   HUNTER2  2025-10-13 13:40:00+00:00  0.0000        0.0
# 989488           NaN   HUNTER2  2025-10-13 13:45:00+00:00  0.0000        0.0
# 989489           NaN   HUNTER2  2025-10-13 13:50:00+00:00  0.0000        0.0
# 989490           NaN   HUNTER2  2025-10-13 13:55:00+00:00  0.0000        0.0
#
#         dispatch_type fueltech_id          name network_id network_region  \
# 0       BIDIRECTIONAL     battery  Melbourne A1        NEM           VIC1
# 1       BIDIRECTIONAL     battery  Melbourne A1        NEM           VIC1
# 2       BIDIRECTIONAL     battery  Melbourne A1        NEM           VIC1
# 3       BIDIRECTIONAL     battery  Melbourne A1        NEM           VIC1
# 4       BIDIRECTIONAL     battery  Melbourne A1        NEM           VIC1
# ...               ...         ...           ...        ...            ...
# 989486            NaN         NaN           NaN        NaN            NaN
# 989487            NaN         NaN           NaN        NaN            NaN
# 989488            NaN         NaN           NaN        NaN            NaN
# 989489            NaN         NaN           NaN        NaN            NaN
# 989490            NaN         NaN           NaN        NaN            NaN
#
#               lat         lng
# 0      -37.661274  144.726302
# 1      -37.661274  144.726302
# 2      -37.661274  144.726302
# 3      -37.661274  144.726302
# 4      -37.661274  144.726302
# ...           ...         ...
# 989486        NaN         NaN
# 989487        NaN         NaN
# 989488        NaN         NaN
# 989489        NaN         NaN
# 989490        NaN         NaN
#
# [989491 rows x 12 columns]

# %%
merged_df.isna().sum()
# Out:
# facility_code     2016
# unit_code            0
# ts                   0
# power                0
# emissions            0
# dispatch_type     2016
# fueltech_id       2016
# name              2016
# network_id        2016
# network_region    2016
# lat               2016
# lng               2016
# dtype: int64

# %%
merged_df["facility_code"].isna().sum()
# Out:
# np.int64(2016)

# %% [markdown]
# *Notice: there are some missing value for facility_code, which is from facility HUNTER, because the api call to facility data only match facility HUNTER with unit HUNTER1, but the facility_metrics provides data for both HUNTER1 and HUNTER2 --> HUNTER2 fail to match*
#
# **Handle**: we can safely drop all data rows for HUNTER, as their power and emission are all 0s, despite being classified as 'operating'

# %% [markdown]
# # **Data Cleaning**

# %%
# Drop rows where facility_code is NA
merged_df = merged_df.dropna(subset=["facility_code", "unit_code"]).copy()

# consistent casing for keys (all uppercase)
merged_df["facility_code"] = merged_df["facility_code"].astype(str).str.upper()
merged_df["unit_code"]     = merged_df["unit_code"].astype(str).str.upper()


# Timestamps: parse to UTC
merged_df["ts"] = pd.to_datetime(merged_df["ts"], utc=True, errors="coerce")

# Ensure numerics for some attributes
for c in ["power", "emissions"]:
    if c in merged_df.columns:
        merged_df[c] = pd.to_numeric(merged_df[c], errors="coerce")

# %%
merged_df["facility_code"].isna().sum()
# Out:
# np.int64(0)

# %% [markdown]
# **There are some facilties that are non-active for the entire period of time ( they have all zero entries for both power and emssion across all units for the entire timeframe) so we do not want to consider that**

# %%
# Remove facilities that are all-zero at every timestamp
#    i.e., for a given facility_code, every row has power==0 AND emissions==0
all_zero_by_row = (merged_df["power"].fillna(0).eq(0) &
                   merged_df["emissions"].fillna(0).eq(0))

all_zero_facilities = all_zero_by_row.groupby(merged_df["facility_code"]).transform("all")

merged_df = merged_df[~all_zero_facilities].copy()
merged_df.reset_index(drop=True, inplace=True)

# %% [markdown]
# **check for duplicates**

# %%
d = merged_df.duplicated(subset=["unit_code","ts"], keep=False)
dupes = merged_df[d].sort_values(["unit_code","ts"])
print(f"Duplicate key rows: {dupes.shape[0]} "
      f"(distinct problematic keys: {dupes[['unit_code','ts']].drop_duplicates().shape[0]})")
# Out:
# Duplicate key rows: 0 (distinct problematic keys: 0)

# %%
merged_df
# Out:
#        facility_code unit_code                        ts   power  emissions  \
# 0              0MREH    MREHA1 2025-10-06 14:00:00+00:00 -3.3805        0.0
# 1              0MREH    MREHA1 2025-10-06 14:05:00+00:00  0.9567        0.0
# 2              0MREH    MREHA1 2025-10-06 14:10:00+00:00 -1.9638        0.0
# 3              0MREH    MREHA1 2025-10-06 14:15:00+00:00  0.5740        0.0
# 4              0MREH    MREHA1 2025-10-06 14:20:00+00:00 -1.9504        0.0
# ...              ...       ...                       ...     ...        ...
# 915997          YSWF     YSWF1 2025-10-13 13:35:00+00:00  0.0000        0.0
# 915998          YSWF     YSWF1 2025-10-13 13:40:00+00:00  0.0000        0.0
# 915999          YSWF     YSWF1 2025-10-13 13:45:00+00:00  0.0000        0.0
# 916000          YSWF     YSWF1 2025-10-13 13:50:00+00:00 -0.1000        0.0
# 916001          YSWF     YSWF1 2025-10-13 13:55:00+00:00  0.0000        0.0
#
#         dispatch_type fueltech_id          name network_id network_region  \
# 0       BIDIRECTIONAL     battery  Melbourne A1        NEM           VIC1
# 1       BIDIRECTIONAL     battery  Melbourne A1        NEM           VIC1
# 2       BIDIRECTIONAL     battery  Melbourne A1        NEM           VIC1
# 3       BIDIRECTIONAL     battery  Melbourne A1        NEM           VIC1
# 4       BIDIRECTIONAL     battery  Melbourne A1        NEM           VIC1
# ...               ...         ...           ...        ...            ...
# 915997      GENERATOR        wind  Yaloak South        NEM           VIC1
# 915998      GENERATOR        wind  Yaloak South        NEM           VIC1
# 915999      GENERATOR        wind  Yaloak South        NEM           VIC1
# 916000      GENERATOR        wind  Yaloak South        NEM           VIC1
# 916001      GENERATOR        wind  Yaloak South        NEM           VIC1
#
#               lat         lng
# 0      -37.661274  144.726302
# 1      -37.661274  144.726302
# 2      -37.661274  144.726302
# 3      -37.661274  144.726302
# 4      -37.661274  144.726302
# ...           ...         ...
# 915997 -37.716474  144.241947
# 915998 -37.716474  144.241947
# 915999 -37.716474  144.241947
# 916000 -37.716474  144.241947
# 916001 -37.716474  144.241947
#
# [916002 rows x 12 columns]

# %% [markdown]
# **Shape the data (order by ts for later publishing)**

# %%
merged_df = merged_df.sort_values(["ts", "facility_code"]).reset_index(drop=True)
merged_df
# Out:
#        facility_code unit_code                        ts    power  emissions  \
# 0              0MREH    MREHA1 2025-10-06 14:00:00+00:00  -3.3805     0.0000
# 1              0MREH   MREHAL1 2025-10-06 14:00:00+00:00   3.3805     0.0000
# 2            0MREHA2    MREHA2 2025-10-06 14:00:00+00:00   0.0000     0.0000
# 3            0MREHA2   MREHAG2 2025-10-06 14:00:00+00:00   0.0000     0.0000
# 4           0WAMBOWF  WAMBOWF1 2025-10-06 14:00:00+00:00  48.5090     0.0000
# ...              ...       ...                       ...      ...        ...
# 915997       YARANSF  YARANSF1 2025-10-13 13:55:00+00:00   0.0000     0.0000
# 915998        YARWUN  YARWUN_1 2025-10-13 13:55:00+00:00  87.5900     4.5247
# 915999        YATSF1    YATSF1 2025-10-13 13:55:00+00:00   0.0000     0.0000
# 916000      YENDONWF   YENDWF1 2025-10-13 13:55:00+00:00   3.2600     0.0000
# 916001          YSWF     YSWF1 2025-10-13 13:55:00+00:00   0.0000     0.0000
#
#         dispatch_type          fueltech_id          name network_id  \
# 0       BIDIRECTIONAL              battery  Melbourne A1        NEM
# 1                LOAD     battery_charging  Melbourne A1        NEM
# 2       BIDIRECTIONAL              battery  Melbourne A2        NEM
# 3           GENERATOR  battery_discharging  Melbourne A2        NEM
# 4           GENERATOR                 wind         Wambo        NEM
# ...               ...                  ...           ...        ...
# 915997      GENERATOR        solar_utility     Yarranlea        NEM
# 915998      GENERATOR             gas_ccgt        Yarwun        NEM
# 915999      GENERATOR        solar_utility       Yatpool        NEM
# 916000      GENERATOR                 wind        Yendon        NEM
# 916001      GENERATOR                 wind  Yaloak South        NEM
#
#        network_region        lat         lng
# 0                VIC1 -37.661274  144.726302
# 1                VIC1 -37.661274  144.726302
# 2                VIC1 -37.663934  144.726927
# 3                VIC1 -37.663934  144.726927
# 4                QLD1 -26.603045  151.246876
# ...               ...        ...         ...
# 915997           QLD1 -27.708939  151.532696
# 915998           QLD1 -23.830200  151.149692
# 915999           VIC1 -34.380730  142.205340
# 916000           VIC1 -37.630952  144.022463
# 916001           VIC1 -37.716474  144.241947
#
# [916002 rows x 12 columns]

# %% [markdown]
# **Remove all the trailing 1s in network region**

# %%
# Get unique values of the 'network_region'
unique_regions = merged_df['network_region'].unique()

print("Unique values in 'network_region':")
display(unique_regions)
# Out:
# Unique values in 'network_region':
# array(['VIC1', 'QLD1', 'SA1', 'NSW1', 'TAS1'], dtype=object)

# %%
# Remove trailing '1' from network_region
merged_df['network_region'] = merged_df['network_region'].astype(str).str.replace('1$', '', regex=True)

print("Network regions after removing trailing '1':")
display(merged_df['network_region'].unique())
# Out:
# Network regions after removing trailing '1':
# array(['VIC', 'QLD', 'SA', 'NSW', 'TAS'], dtype=object)

# %%
merged_df["network_region"].unique()
# Out:
# array(['VIC', 'QLD', 'SA', 'NSW', 'TAS'], dtype=object)

# %% [markdown]
# # **Data Publishing**

# %%
# !pip install paho-mqtt
# Out:
# Collecting paho-mqtt
#   Downloading paho_mqtt-2.1.0-py3-none-any.whl.metadata (23 kB)
# Downloading paho_mqtt-2.1.0-py3-none-any.whl (67 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.2/67.2 kB 2.0 MB/s eta 0:00:00
# Installing collected packages: paho-mqtt
# Successfully installed paho-mqtt-2.1.0

# %%
import paho.mqtt.client as mqtt

# %% [markdown]
# **Setting up clients**

# %%
import json, time
from paho.mqtt import client as mqtt
import math

# Broker info
BROKER_HOST = "broker.hivemq.com"
BROKER_PORT = 1883
CLIENT_ID    = "5339-ass2-facility-publisher"
BASE_TOPIC   = "facility"

# MQTT client
client = mqtt.Client(client_id=CLIENT_ID, clean_session=True)
client.reconnect_delay_set(min_delay=1, max_delay=30)

def on_connect(cli, userdata, flags, rc):
    print(f"Connected with result code {rc}")

def on_publish(cli, userdata, mid):
    pass

client.on_connect  = on_connect
client.on_publish  = on_publish

client.connect(BROKER_HOST, BROKER_PORT, keepalive=60)
client.loop_start()
# Out:
# /tmp/ipython-input-266698249.py:12: DeprecationWarning: Callback API version 1 is deprecated, update to latest version
#   client = mqtt.Client(client_id=CLIENT_ID, clean_session=True)
# <MQTTErrorCode.MQTT_ERR_SUCCESS: 0>

# %% [markdown]
# **Start publishing**

# %% [markdown]
# The code below set up the MQTT client and start publishing
#
# To target the 'only updated power/emissions values are published' issue, we use a hashmap to store previous facility units details and compare it to current details to see if there's any change, if there's no change, we will not publish it. Full detailed analysis in the report.

# %%
REPLAY_COOLDOWN_SECS = 60  # wait before restarting when we hit the end

#  Some other settings
PUBLISH_QOS    = 1            # At most 1 semantic
RETAIN_LAST    = False
ROW_DELAY_SECS = 0.1



# Guarantee that "only updated power/emissions values are published" as spcified in ED FAQ
last_vals = {}      # this is a hashmap with key and value (facility_code, unit_code) -> (power, emissions)
def same(a, b):
    if a is None and b is None: return True
    if (a is None) ^ (b is None): return False
    return math.isclose(a, b, rel_tol=0.0, abs_tol=1e-6)

# Start the publishing loop
while True:
    # reset per-replay cache so first occurrences publish again
    last_vals.clear()

    for ts_value, batch in merged_df.groupby("ts", sort=True):
        print(f"\n Publishing batch for timestamp {ts_value}")

        for row in batch.itertuples(index=False):
            facility_code_cleaned = row.facility_code.replace('+','').replace('#','')
            unit_code_cleaned     = row.unit_code.replace('+','').replace('#','')

            # current values (coerce to floats/None)
            cur_power     = float(row.power)     if pd.notna(row.power)     else None
            cur_emissions = float(row.emissions) if pd.notna(row.emissions) else None

            key  = (row.facility_code, row.unit_code)
            prev = last_vals.get(key)

            # skip if unchanged since last publish (within this replay)
            if prev is not None and same(cur_power, prev[0]) and same(cur_emissions, prev[1]):
                continue

            topic = f"facility/{facility_code_cleaned}/{unit_code_cleaned}"
            payload = json.dumps({
                "facility_code": row.facility_code if pd.notna(row.facility_code) else None,
                "unit_code":     row.unit_code     if pd.notna(row.unit_code)     else None,
                "state":         row.network_region if pd.notna(row.network_region) else None,
                "lat":           float(row.lat)    if pd.notna(row.lat)    else None,
                "lng":           float(row.lng)    if pd.notna(row.lng)    else None,
                "fueltech_id":   row.fueltech_id   if pd.notna(row.fueltech_id)   else None,
                "ts":            ts_value.strftime("%Y-%m-%dT%H:%M:%SZ"),
                "power":         float(row.power)      if pd.notna(row.power)      else None,
                "emissions":     float(row.emissions)  if pd.notna(row.emissions)  else None,
                "dispatch_type": row.dispatch_type if pd.notna(row.dispatch_type) else None,
                "name":          row.name          if pd.notna(row.name)          else None,
                "network_id":    row.network_id    if pd.notna(row.network_id)    else None,
            })

            info = client.publish(topic, payload, qos=PUBLISH_QOS, retain=RETAIN_LAST)
            info.wait_for_publish()
            print(f"Published → {topic}: {payload}")

            last_vals[key] = (cur_power, cur_emissions)

        time.sleep(ROW_DELAY_SECS)

    print(f"\nReached end of dataset — waiting {REPLAY_COOLDOWN_SECS}s, then restarting replay.")
    time.sleep(REPLAY_COOLDOWN_SECS)
# Out:
# Streaming output truncated to the last 5000 lines.
# Published → facility/YSWF/YSWF1: {"facility_code": "YSWF", "unit_code": "YSWF1", "state": "VIC", "lat": -37.716474, "lng": 144.241947, "fueltech_id": "wind", "ts": "2025-10-06T15:25:00Z", "power": 0.9, "emissions": 0.0, "dispatch_type": "GENERATOR", "name": "Yaloak South", "network_id": "NEM"}
#
#  Publishing batch for timestamp 2025-10-06 15:30:00+00:00
# Published → facility/0WAMBOWF/WAMBOWF1: {"facility_code": "0WAMBOWF", "unit_code": "WAMBOWF1", "state": "QLD", "lat": -26.603045, "lng": 151.246876, "fueltech_id": "wind", "ts": "2025-10-06T15:30:00Z", "power": 30.816, "emissions": 0.0, "dispatch_type": "GENERATOR", "name": "Wambo", "network_id": "NEM"}
# Published → facility/ADP/ADPBA1: {"facility_code": "ADP", "unit_code": "ADPBA1", "state": "SA", "lat": -35.096948, "lng": 138.484061, "fueltech_id": "battery", "ts": "2025-10-06T15:30:00Z", "power": 0.088, "emissions": 0.0, "dispatch_type": "BIDIRECTIONAL", "name": "Adelaide Desalination", "network_id": "NEM"}
# Published → facility/ADP/ADPBA1G: {"facility_code": "ADP", "unit_code": "ADPBA1G", "state": "SA", "lat": -35.096948, "lng": 138.484061, "fueltech_id": "battery_discharging", "ts": "2025-10-06T15:30:00Z", "power": 0.088, "emissions": 0.0, "dispatch_type": "GENERATOR", "name": "Adelaide Desalination", "network_id": "NEM"}
# Published → facility/ARWF/ARWF1: {"facility_code": "ARWF", "unit_code": "ARWF1", "state": "VIC", "lat": -37.263393, "lng": 143.082116, "fueltech_id": "wind", "ts": "2025-10-06T15:30:00Z", "power": 3.7, "emissions": 0.0, "dispatch_type": "GENERATOR", "name": "Ararat", "network_id": "NEM"}
# Published → facility/BALBESS/BALB1: {"facility_code": "BALBESS", "unit_code": "BALB1", "state": "VIC", "lat": -37.567452, "lng": 143.852741, "fueltech_id": "battery", "ts": "2025-10-06T15:30:00Z", "power": 9.82, "emissions": 0.0, "dispatch_type": "BIDIRECTIONAL", "name": "Ballarat", "network_id": "NEM"}
# Published → facility/BALBESS/BALBG1: {"facility_code": "BALBESS", "unit_code": "BALBG1", "state": "VIC", "lat": -37.567452, "lng": 143.852741, "fueltech_id": "battery_discharging", "ts": "2025-10-06T15:30:00Z", "power": 9.82, "emissions": 0.0, "dispatch_type": "GENERATOR", "name": "Ballarat", "network_id": "NEM"}
# Published → facility/BANGOWF/BANGOWF1: {"facility_code": "BANGOWF", "unit_code": "BANGOWF1", "state": "NSW", "lat": -34.767208, "lng": 148.921499, "fueltech_id": "wind", "ts": "2025-10-06T15:30:00Z", "power": 2.6978, "emissions": 0.0, "dispatch_type": "GENERATOR", "name": "Bango", "network_id": "NEM"}
# Published → facility/BANGOWF/BANGOWF2: {"facility_code": "BANGOWF", "unit_code": "BANGOWF2", "state": "NSW", "lat": -34.767208, "lng": 148.921499, "fueltech_id": "wind", "ts": "2025-10-06T15:30:00Z", "power": 3.799, "emissions": 0.0, "dispatch_type": "GENERATOR", "name": "Bango", "network_id": "NEM"}
# Published → facility/BARKIPS/BARKIPS1: {"facility_code": "BARKIPS", "unit_code": "BARKIPS1", "state": "SA", "lat": -34.804, "lng": 138.524, "fueltech_id": "gas_recip", "ts": "2025-10-06T15:30:00Z", "power": 139.25, "emissions": 6.843, "dispatch_type": "GENERATOR", "name": "Barker Inlet", "network_id": "NEM"}
# Published → facility/BASTYAN/BASTYAN: {"facility_code": "BASTYAN", "unit_code": "BASTYAN", "state": "TAS", "lat": -41.736231, "lng": 145.531589, "fueltech_id": "hydro", "ts": "2025-10-06T15:30:00Z", "power": 76.33, "emissions": 0.0, "dispatch_type": "GENERATOR", "name": "Bastyan", "network_id": "NEM"}
# Published → facility/BAYSW/BW01: {"facility_code": "BAYSW", "unit_code": "BW01", "state": "NSW", "lat": -32.393502, "lng": 150.953963, "fueltech_id": "coal_black", "ts": "2025-10-06T15:30:00Z", "power": 660.032, "emissions": 49.0569, "dispatch_type": "GENERATOR", "name": "Bayswater", "network_id": "NEM"}
# Published → facility/BAYSW/BW02: {"facility_code": "BAYSW", "unit_code": "BW02", "state": "NSW", "lat": -32.393502, "lng": 150.953963, "fueltech_id": "coal_black", "ts": "2025-10-06T15:30:00Z", "power": 329.8512, "emissions": 24.5162, "dispatch_type": "GENERATOR", "name": "Bayswater", "network_id": "NEM"}
# Published → facility/BAYSW/BW03: {"facility_code": "BAYSW", "unit_code": "BW03", "state": "NSW", "lat": -32.393502, "lng": 150.953963, "fueltech_id": "coal_black", "ts": "2025-10-06T15:30:00Z", "power": 684.2756, "emissions": 50.8588, "dispatch_type": "GENERATOR", "name": "Bayswater", "network_id": "NEM"}
# Published → facility/BBATTERY/BBATRYL1: {"facility_code": "BBATTERY", "unit_code": "BBATRYL1", "state": "QLD", "lat": -23.563443, "lng": 150.459658, "fueltech_id": "battery_charging", "ts": "2025-10-06T15:30:00Z", "power": 0.8111, "emissions": 0.0, "dispatch_type": "LOAD", "name": "Bouldercombe", "network_id": "NEM"}
# Published → facility/BBATTERY/BBATTERY1: {"facility_code": "BBATTERY", "unit_code": "BBATTERY1", "state": "QLD", "lat": -23.563443, "lng": 150.459658, "fueltech_id": "battery", "ts": "2025-10-06T15:30:00Z", "power": -0.8111, "emissions": 0.0, "dispatch_type": "BIDIRECTIONAL", "name": "Bouldercombe", "network_id": "NEM"}
# Published → facility/BHB/BHB1: {"facility_code": "BHB", "unit_code": "BHB1", "state": "NSW", "lat": -31.9863, "lng": 141.4204, "fueltech_id": "battery", "ts": "2025-10-06T15:30:00Z", "power": -1.9009, "emissions": 0.0, "dispatch_type": "BIDIRECTIONAL", "name": "Broken Hill Battery", "network_id": "NEM"}
# Published → facility/BHB/BHBL1: {"facility_code": "BHB", "unit_code": "BHBL1", "state": "NSW", "lat": -31.9863, "lng": 141.4204, "fueltech_id": "battery_charging", "ts": "2025-10-06T15:30:00Z", "power": 1.9009, "emissions": 0.0, "dispatch_type": "LOAD", "name": "Broken Hill Battery", "network_id": "NEM"}
# Published → facility/BHWF/BALDHWF1: {"facility_code": "BHWF", "unit_code": "BALDHWF1", "state": "VIC", "lat": -38.758189, "lng": 145.956062, "fueltech_id": "wind", "ts": "2025-10-06T15:30:00Z", "power": 42.464, "emissions": 0.0, "dispatch_type": "GENERATOR", "name": "Bald Hills", "network_id": "NEM"}
# Published → facility/BLYTHB/BLYTHB1: {"facility_code": "BLYTHB", "unit_code": "BLYTHB1", "state": "SA", "lat": -33.848475, "lng": 138.403204, "fueltech_id": "battery", "ts": "2025-10-06T15:30:00Z", "power": 0.85, "emissions": 0.0, "dispatch_type": "BIDIRECTIONAL", "name": "Blyth", "network_id": "NEM"}
# Published → facility/BLYTHB/BLYTHB1G1: {"facility_code": "BLYTHB", "unit_code": "BLYTHB1G1", "state": "SA", "lat": -33.848475, "lng": 138.403204, "fueltech_id": "battery_discharging", "ts": "2025-10-06T15:30:00Z", "power": 0.85, "emissions": 0.0, "dispatch_type": "GENERATOR", "name": "Blyth", "network_id": "NEM"}
# Published → facility/BODWF/BODWF1: {"facility_code": "BODWF", "unit_code": "BODWF1", "state": "NSW", "lat": -32.407128, "lng": 149.04133, "fueltech_id": "wind", "ts": "2025-10-06T15:30:00Z", "power": 38.8193, "emissions": 0.0, "dispatch_type": "GENERATOR", "name": "Bodangora", "network_id": "NEM"}
# Published → facility/BOLIVAR/BOWWBA1: {"facility_code": "BOLIVAR", "unit_code": "BOWWBA1", "state": "SA", "lat": -34.495482, "lng": 138.387641, "fueltech_id": "battery", "ts": "2025-10-06T15:30:00Z", "power": 0.004, "emissions": 0.0, "dispatch_type": "BIDIRECTIONAL", "name": "Bolivar", "network_id": "NEM"}
# Published → facility/BOLIVAR/BOWWBA1G: {"facility_code": "BOLIVAR", "unit_code": "BOWWBA1G", "state": "SA", "lat": -34.495482, "lng": 138.387641, "fueltech_id": "battery_discharging", "ts": "2025-10-06T15:30:00Z", "power": 0.004, "emissions": 0.0, "dispatch_type": "GENERATOR", "name": "Bolivar", "network_id": "NEM"}
# Published → facility/BRYB1WF1/BRYB1WF1: {"facility_code": "BRYB1WF1", "unit_code": "BRYB1WF1", "state": "VIC", "lat": -37.980741, "lng": 143.472217, "fueltech_id": "wind", "ts": "2025-10-06T15:30:00Z", "power": 45.9693, "emissions": 0.0, "dispatch_type": "GENERATOR", "name": "Berrybank", "network_id": "NEM"}
# Published → facility/BRYB1WF1/BRYB2WF2: {"facility_code": "BRYB1WF1", "unit_code": "BRYB2WF2", "state": "VIC", "lat": -37.980741, "lng": 143.472217, "fueltech_id": "wind", "ts": "2025-10-06T15:30:00Z", "power": 25.4612, "emissions": 0.0, "dispatch_type": "GENERATOR", "name": "Berrybank", "network_id": "NEM"}
# Published → facility/BULGANA/BULBES1: {"facility_code": "BULGANA", "unit_code": "BULBES1", "state": "VIC", "lat": -37.039507, "lng": 142.982799, "fueltech_id": "battery", "ts": "2025-10-06T15:30:00Z", "power": 0.09, "emissions": 0.0, "dispatch_type": "BIDIRECTIONAL", "name": "Bulgana Green Power Hub", "network_id": "NEM"}
# Published → facility/BULGANA/BULBESG1: {"facility_code": "BULGANA", "unit_code": "BULBESG1", "state": "VIC", "lat": -37.039507, "lng": 142.982799, "fueltech_id": "battery_discharging", "ts": "2025-10-06T15:30:00Z", "power": 0.09, "emissions": 0.0, "dispatch_type": "GENERATOR", "name": "Bulgana Green Power Hub", "network_id": "NEM"}
# Published → facility/BULGANA/BULGANA1: {"facility_code": "BULGANA", "unit_code": "BULGANA1", "state": "VIC", "lat": -37.039507, "lng": 142.982799, "fueltech_id": "wind", "ts": "2025-10-06T15:30:00Z", "power": 16.81, "emissions": 0.0, "dispatch_type": "GENERATOR", "name": "Bulgana Green Power Hub", "network_id": "NEM"}
# Published → facility/CALLIDEC1/CPP_4: {"facility_code": "CALLIDEC1", "unit_code": "CPP_4", "state": "QLD", "lat": -24.347222, "lng": 150.608611, "fueltech_id": "coal_black", "ts": "2025-10-06T15:30:00Z", "power": 240.625, "emissions": 17.7862, "dispatch_type": "GENERATOR", "name": "Callide C", "network_id": "NEM"}
# Published → facility/CALL_B/CALL_B_1: {"facility_code": "CALL_B", "unit_code": "CALL_B_1", "state": "QLD", "lat": -24.333169, "lng": 150.626322, "fueltech_id": "coal_black", "ts": "2025-10-06T15:30:00Z", "power": 320.7, "emissions": 25.5384, "dispatch_type": "GENERATOR", "name": "Callide B", "network_id": "NEM"}
# Published → facility/CANUNDA1/CNUNDAWF: {"facility_code": "CANUNDA1", "unit_code": "CNUNDAWF", "state": "SA", "lat": -37.698303, "lng": 140.383633, "fueltech_id": "wind", "ts": "2025-10-06T15:30:00Z", "power": 10.7125, "emissions": 0.0, "dispatch_type": "GENERATOR", "name": "Canunda", "network_id": "NEM"}
# Published → facility/CAPBES/CAPBES1: {"facility_code": "CAPBES", "unit_code": "CAPBES1", "state": "NSW", "lat": -35.339434, "lng": 149.216065, "fueltech_id": "battery", "ts": "2025-10-06T15:30:00Z", "power": -0.24, "emissions": 0.0, "dispatch_type": "BIDIRECTIONAL", "name": "Capital", "network_id": "NEM"}
# Published → facility/CAPBES/CAPBES1L: {"facility_code": "CAPBES", "unit_code": "CAPBES1L", "state": "NSW", "lat": -35.339434, "lng": 149.216065, "fueltech_id": "battery_charging", "ts": "2025-10-06T15:30:00Z", "power": 0.24, "emissions": 0.0, "dispatch_type": "LOAD", "name": "Capital", "network_id": "NEM"}
# Published → facility/CATHROCK/CATHROCK: {"facility_code": "CATHROCK", "unit_code": "CATHROCK", "state": "SA", "lat": -34.848741, "lng": 135.592649, "fueltech_id": "wind", "ts": "2025-10-06T15:30:00Z", "power": 5.4, "emissions": 0.0, "dispatch_type": "GENERATOR", "name": "Cathedral Rocks", "network_id": "NEM"}
# Published → facility/CBWWBA/CBWWBA1: {"facility_code": "CBWWBA", "unit_code": "CBWWBA1", "state": "SA", "lat": -35.125958, "lng": 138.47135, "fueltech_id": "battery", "ts": "2025-10-06T15:30:00Z", "power": 0.046, "emissions": 0.0, "dispatch_type": "BIDIRECTIONAL", "name": "Christies Beach", "network_id": "NEM"}
# Published → facility/CBWWBA/CBWWBA1G: {"facility_code": "CBWWBA", "unit_code": "CBWWBA1G", "state": "SA", "lat": -35.125958, "lng": 138.47135, "fueltech_id": "battery_discharging", "ts": "2025-10-06T15:30:00Z", "power": 0.046, "emissions": 0.0, "dispatch_type": "GENERATOR", "name": "Christies Beach", "network_id": "NEM"}
# Published → facility/CETHANA/CETHANA: {"facility_code": "CETHANA", "unit_code": "CETHANA", "state": "TAS", "lat": -41.479852, "lng": 146.134472, "fueltech_id": "hydro", "ts": "2025-10-06T15:30:00Z", "power": 5.498, "emissions": 0.0, "dispatch_type": "GENERATOR", "name": "Cethana", "network_id": "NEM"}
# Published → facility/CLEMGPWF/CLEMGPWF: {"facility_code": "CLEMGPWF", "unit_code": "CLEMGPWF", "state": "SA", "lat": -33.489773, "lng": 138.111695, "fueltech_id": "wind", "ts": "2025-10-06T15:30:00Z", "power": 2.7373, "emissions": 0.0, "dispatch_type": "GENERATOR", "name": "Clements Gap", "network_id": "NEM"}
# Published → facility/CLRKCWF/CLRKCWF1: {"facility_code": "CLRKCWF", "unit_code": "CLRKCWF1", "state": "QLD", "lat": -22.850446, "lng": 149.453252, "fueltech_id": "wind", "ts": "2025-10-06T15:30:00Z", "power": 290.357, "emissions": 0.0, "dispatch_type": "GENERATOR", "name": "Clarke Creek", "network_id": "NEM"}
# Published → facility/CLRKCWF/CLRKCWF2: {"facility_code": "CLRKCWF", "unit_code": "CLRKCWF2", "state": "QLD", "lat": -22.850446, "lng": 149.453252, "fueltech_id": "wind", "ts": "2025-10-06T15:30:00Z", "power": 23.1813, "emissions": 0.0, "dispatch_type": "GENERATOR", "name": "Clarke Creek", "network_id": "NEM"}
# Published → facility/CLUNY/CLUNY: {"facility_code": "CLUNY", "unit_code": "CLUNY", "state": "TAS", "lat": -42.506229, "lng": 146.681123, "fueltech_id": "hydro", "ts": "2025-10-06T15:30:00Z", "power": 1.9716, "emissions": 0.0, "dispatch_type": "GENERATOR", "name": "Cluny", "network_id": "NEM"}
# Published → facility/COLWF01/COLWF01: {"facility_code": "COLWF01", "unit_code": "COLWF01", "state": "NSW", "lat": -34.823879, "lng": 149.396795, "fueltech_id": "wind", "ts": "2025-10-06T15:30:00Z", "power": 0.0, "emissions": 0.0, "dispatch_type": "GENERATOR", "name": "Collector", "network_id": "NEM"}
# Published → facility/CONDONG1/CONDONG1: {"facility_code": "CONDONG1", "unit_code": "CONDONG1", "state": "NSW", "lat": -28.314766, "lng": 153.433808, "fueltech_id": "bioenergy_biomass", "ts": "2025-10-06T15:30:00Z", "power": 24.46, "emissions": 0.0746, "dispatch_type": "GENERATOR", "name": "Condong", "network_id": "NEM"}
# Published → facility/COOPGWF/COOPGWF1: {"facility_code": "COOPGWF", "unit_code": "COOPGWF1", "state": "QLD", "lat": -26.717004, "lng": 151.449177, "fueltech_id": "wind", "ts": "2025-10-06T15:30:00Z", "power": 143.75, "emissions": 0.0, "dispatch_type": "GENERATOR", "name": "Coopers Gap", "network_id": "NEM"}
# Published → facility/CROOKWF2/CROOKWF2: {"facility_code": "CROOKWF2", "unit_code": "CROOKWF2", "state": "NSW", "lat": -34.547676, "lng": 149.589254, "fueltech_id": "wind", "ts": "2025-10-06T15:30:00Z", "power": 1.4881, "emissions": 0.0, "dispatch_type": "GENERATOR", "name": "Crookwell 2", "network_id": "NEM"}
# Published → facility/CROOKWF3/CROOKWF3: {"facility_code": "CROOKWF3", "unit_code": "CROOKWF3", "state": "NSW", "lat": -34.484645, "lng": 149.54447, "fueltech_id": "wind", "ts": "2025-10-06T15:30:00Z", "power": 2.3045, "emissions": 0.0, "dispatch_type": "GENERATOR", "name": "Crookwell 3", "network_id": "NEM"}
# Published → facility/CROWLWF/CROWLWF1: {"facility_code": "CROWLWF", "unit_code": "CROWLWF1", "state": "VIC", "lat": -36.97615, "lng": 143.097998, "fueltech_id": "wind", "ts": "2025-10-06T15:30:00Z", "power": 12.3592, "emissions": 0.0, "dispatch_type": "GENERATOR", "name": "Crowlands", "network_id": "NEM"}
# Published → facility/CRURWF1/CRURWF1: {"facility_code": "CRURWF1", "unit_code": "CRURWF1", "state": "NSW", "lat": -32.864748, "lng": 149.81297, "fueltech_id": "wind", "ts": "2025-10-06T15:30:00Z", "power": 1.0996, "emissions": 0.0, "dispatch_type": "GENERATOR", "name": "Crudine Ridge", "network_id": "NEM"}
# Published → facility/CTHLWF/CTHLWF1: {"facility_code": "CTHLWF", "unit_code": "CTHLWF1", "state": "TAS", "lat": -42.154845, "lng": 146.694693, "fueltech_id": "wind", "ts": "2025-10-06T15:30:00Z", "power": 122.7833, "emissions": 0.0, "dispatch_type": "GENERATOR", "name": "Cattle Hill", "network_id": "NEM"}
# Published → facility/CULLERIN/CULLRGWF: {"facility_code": "CULLERIN", "unit_code": "CULLRGWF", "state": "NSW", "lat": -34.750995, "lng": 149.381027, "fueltech_id": "wind", "ts": "2025-10-06T15:30:00Z", "power": 1.73, "emissions": 0.0, "dispatch_type": "GENERATOR", "name": "Cullerin Range", "network_id": "NEM"}
# Published → facility/DALNTH/DALNTH1: {"facility_code": "DALNTH", "unit_code": "DALNTH1", "state": "SA", "lat": -34.888446, "lng": 137.758114, "fueltech_id": "battery", "ts": "2025-10-06T15:30:00Z", "power": -0.1907, "emissions": 0.0, "dispatch_type": "BIDIRECTIONAL", "name": "Dalrymple North", "network_id": "NEM"}
# Published → facility/DALNTH/DALNTHL1: {"facility_code": "DALNTH", "unit_code": "DALNTHL1", "state": "SA", "lat": -34.888446, "lng": 137.758114, "fueltech_id": "battery_charging", "ts": "2025-10-06T15:30:00Z", "power": 0.1907, "emissions": 0.0, "dispatch_type": "LOAD", "name": "Dalrymple North", "network_id": "NEM"}
# Published → facility/DEVILS_G/DEVILS_G: {"facility_code": "DEVILS_G", "unit_code": "DEVILS_G", "state": "TAS", "lat": -41.349925, "lng": 146.262709, "fueltech_id": "hydro", "ts": "2025-10-06T15:30:00Z", "power": 22.7961, "emissions": 0.0, "dispatch_type": "GENERATOR", "name": "Devils Gate", "network_id": "NEM"}
# Published → facility/DIAPURWF/DIAPURWF1: {"facility_code": "DIAPURWF", "unit_code": "DIAPURWF1", "state": "VIC", "lat": -36.339953, "lng": 141.447361, "fueltech_id": "wind", "ts": "2025-10-06T15:30:00Z", "power": 1.5, "emissions": 0.0, "dispatch_type": "GENERATOR", "name": "Diapur 2", "network_id": "NEM"}
# Published → facility/DPNTB/DPNTB1: {"facility_code": "DPNTB", "unit_code": "DPNTB1", "state": "NSW", "lat": -34.646668, "lng": 146.034982, "fueltech_id": "battery", "ts": "2025-10-06T15:30:00Z", "power": 0.0254, "emissions": 0.0, "dispatch_type": "BIDIRECTIONAL", "name": "Darlington Point", "network_id": "NEM"}
# Published → facility/DPNTB/DPNTBG1: {"facility_code": "DPNTB", "unit_code": "DPNTBG1", "state": "NSW", "lat": -34.646668, "lng": 146.034982, "fueltech_id": "battery_discharging", "ts": "2025-10-06T15:30:00Z", "power": 0.0254, "emissions": 0.0, "dispatch_type": "GENERATOR", "name": "Darlington Point", "network_id": "NEM"}
# Published → facility/DULAWF/DULAWF1: {"facility_code": "DULAWF", "unit_code": "DULAWF1", "state": "QLD", "lat": -26.637485, "lng": 149.870186, "fueltech_id": "wind", "ts": "2025-10-06T15:30:00Z", "power": 171.8, "emissions": 0.0, "dispatch_type": "GENERATOR", "name": "Dulacca", "network_id": "NEM"}
# Published → facility/DUNDWF/DUNDWF1: {"facility_code": "DUNDWF", "unit_code": "DUNDWF1", "state": "VIC", "lat": -37.863894, "lng": 142.943454, "fueltech_id": "wind", "ts": "2025-10-06T15:30:00Z", "power": 76.61, "emissions": 0.0, "dispatch_type": "GENERATOR", "name": "Dundonnell", "network_id": "NEM"}
# Published → facility/DUNDWF/DUNDWF2: {"facility_code": "DUNDWF", "unit_code": "DUNDWF2", "state": "VIC", "lat": -37.863894, "lng": 142.943454, "fueltech_id": "wind", "ts": "2025-10-06T15:30:00Z", "power": 14.05, "emissions": 0.0, "dispatch_type": "GENERATOR", "name": "Dundonnell", "network_id": "NEM"}
# Published → facility/DUNDWF/DUNDWF3: {"facility_code": "DUNDWF", "unit_code": "DUNDWF3", "state": "VIC", "lat": -37.863894, "lng": 142.943454, "fueltech_id": "wind", "ts": "2025-10-06T15:30:00Z", "power": 34.55, "emissions": 0.0, "dispatch_type": "GENERATOR", "name": "Dundonnell", "network_id": "NEM"}
# Published → facility/EILDON/EILDON1: {"facility_code": "EILDON", "unit_code": "EILDON1", "state": "VIC", "lat": -37.221262, "lng": 145.920966, "fueltech_id": "hydro", "ts": "2025-10-06T15:30:00Z", "power": 43.0, "emissions": 0.0, "dispatch_type": "GENERATOR", "name": "Eildon", "network_id": "NEM"}
# Published → facility/ELAINEWF/ELAINWF1: {"facility_code": "ELAINEWF", "unit_code": "ELAINWF1", "state": "VIC", "lat": -37.6352, "lng": 144.0237, "fueltech_id": "wind", "ts": "2025-10-06T15:30:00Z", "power": 8.46, "emissions": 0.0, "dispatch_type": "GENERATOR", "name": "Elaine", "network_id": "NEM"}
# Published → facility/ERARING/ER01: {"facility_code": "ERARING", "unit_code": "ER01", "state": "NSW", "lat": -33.061548, "lng": 151.524612, "fueltech_id": "coal_black", "ts": "2025-10-06T15:30:00Z", "power": 679.7833, "emissions": 50.5306, "dispatch_type": "GENERATOR", "name": "Eraring", "network_id": "NEM"}
# Published → facility/ERARING/ER02: {"facility_code": "ERARING", "unit_code": "ER02", "state": "NSW", "lat": -33.061548, "lng": 151.524612, "fueltech_id": "coal_black", "ts": "2025-10-06T15:30:00Z", "power": 684.7394, "emissions": 50.8989, "dispatch_type": "GENERATOR", "name": "Eraring", "network_id": "NEM"}
# Published → facility/FISHER/FISHER: {"facility_code": "FISHER", "unit_code": "FISHER", "state": "TAS", "lat": -41.672662, "lng": 146.268739, "fueltech_id": "hydro", "ts": "2025-10-06T15:30:00Z", "power": 10.39, "emissions": 0.0, "dispatch_type": "GENERATOR", "name": "Fisher", "network_id": "NEM"}
# Published → facility/GANNBESS/GANNB1: {"facility_code": "GANNBESS", "unit_code": "GANNB1", "state": "VIC", "lat": -33.735056, "lng": 143.779462, "fueltech_id": "battery", "ts": "2025-10-06T15:30:00Z", "power": 12.1016, "emissions": 0.0, "dispatch_type": "BIDIRECTIONAL", "name": "Gannawarra", "network_id": "NEM"}
# Published → facility/GANNBESS/GANNBG1: {"facility_code": "GANNBESS", "unit_code": "GANNBG1", "state": "VIC", "lat": -33.735056, "lng": 143.779462, "fueltech_id": "battery_discharging", "ts": "2025-10-06T15:30:00Z", "power": 12.1016, "emissions": 0.0, "dispatch_type": "GENERATOR", "name": "Gannawarra", "network_id": "NEM"}
# Published → facility/GERMCRK/GERMCRK: {"facility_code": "GERMCRK", "unit_code": "GERMCRK", "state": "QLD", "lat": -22.928526, "lng": 148.549097, "fueltech_id": "gas_wcmg", "ts": "2025-10-06T15:30:00Z", "power": 17.18, "emissions": 0.8099, "dispatch_type": "GENERATOR", "name": "German Creek", "network_id": "NEM"}
# Published → facility/GORDON/GORDON: {"facility_code": "GORDON", "unit_code": "GORDON", "state": "TAS", "lat": -42.740157, "lng": 145.983375, "fueltech_id": "hydro", "ts": "2025-10-06T15:30:00Z", "power": 22.4088, "emissions": 0.0, "dispatch_type": "GENERATOR", "name": "Gordon", "network_id": "NEM"}
# Published → facility/GPWFEST/GPWFEST1: {"facility_code": "GPWFEST", "unit_code": "GPWFEST1", "state": "VIC", "lat": -37.9729, "lng": 143.783, "fueltech_id": "wind", "ts": "2025-10-06T15:30:00Z", "power": 46.64, "emissions": 0.0, "dispatch_type": "GENERATOR", "name": "Golden Plains East", "network_id": "NEM"}
# Published → facility/GPWFEST/GPWFEST2: {"facility_code": "GPWFEST", "unit_code": "GPWFEST2", "state": "VIC", "lat": -37.9729, "lng": 143.783, "fueltech_id": "wind", "ts": "2025-10-06T15:30:00Z", "power": 27.42, "emissions": 0.0, "dispatch_type": "GENERATOR", "name": "Golden Plains East", "network_id": "NEM"}
# Published → facility/GPWFEST/GPWFEST3: {"facility_code": "GPWFEST", "unit_code": "GPWFEST3", "state": "VIC", "lat": -37.9729, "lng": 143.783, "fueltech_id": "wind", "ts": "2025-10-06T15:30:00Z", "power": 57.62, "emissions": 0.0, "dispatch_type": "GENERATOR", "name": "Golden Plains East", "network_id": "NEM"}
# Published → facility/GRANWF/GRANWF1: {"facility_code": "GRANWF", "unit_code": "GRANWF1", "state": "TAS", "lat": -41.802, "lng": 145.056, "fueltech_id": "wind", "ts": "2025-10-06T15:30:00Z", "power": 59.15, "emissions": 0.0, "dispatch_type": "GENERATOR", "name": "Granville Harbour", "network_id": "NEM"}
# Published → facility/GREENB/GREENB1: {"facility_code": "GREENB", "unit_code": "GREENB1", "state": "QLD", "lat": -27.733562, "lng": 152.955042, "fueltech_id": "battery", "ts": "2025-10-06T15:30:00Z", "power": 0.5519, "emissions": 0.0, "dispatch_type": "BIDIRECTIONAL", "name": "Greenbank", "network_id": "NEM"}
# Published → facility/GREENB/GREENB1G1: {"facility_code": "GREENB", "unit_code": "GREENB1G1", "state": "QLD", "lat": -27.733562, "lng": 152.955042, "fueltech_id": "battery_discharging", "ts": "2025-10-06T15:30:00Z", "power": 0.5519, "emissions": 0.0, "dispatch_type": "GENERATOR", "name": "Greenbank", "network_id": "NEM"}
# Published → facility/GSTONE/GSTONE1: {"facility_code": "GSTONE", "unit_code": "GSTONE1", "state": "QLD", "lat": -23.848741, "lng": 151.220787, "fueltech_id": "coal_black", "ts": "2025-10-06T15:30:00Z", "power": 149.8506, "emissions": 12.1853, "dispatch_type": "GENERATOR", "name": "Gladstone", "network_id": "NEM"}
# Published → facility/GSTONE/GSTONE2: {"facility_code": "GSTONE", "unit_code": "GSTONE2", "state": "QLD", "lat": -23.848741, "lng": 151.220787, "fueltech_id": "coal_black", "ts": "2025-10-06T15:30:00Z", "power": 149.7002, "emissions": 12.1731, "dispatch_type": "GENERATOR", "name": "Gladstone", "network_id": "NEM"}
# Published → facility/GSTONE/GSTONE3: {"facility_code": "GSTONE", "unit_code": "GSTONE3", "state": "QLD", "lat": -23.848741, "lng": 151.220787, "fueltech_id": "coal_black", "ts": "2025-10-06T15:30:00Z", "power": 149.7549, "emissions": 12.1776, "dispatch_type": "GENERATOR", "name": "Gladstone", "network_id": "NEM"}
# Published → facility/GSTONE/GSTONE4: {"facility_code": "GSTONE", "unit_code": "GSTONE4", "state": "QLD", "lat": -23.848741, "lng": 151.220787, "fueltech_id": "coal_black", "ts": "2025-10-06T15:30:00Z", "power": 149.8643, "emissions": 12.1865, "dispatch_type": "GENERATOR", "name": "Gladstone", "network_id": "NEM"}
# Published → facility/GSTONE/GSTONE6: {"facility_code": "GSTONE", "unit_code": "GSTONE6", "state": "QLD", "lat": -23.848741, "lng": 151.220787, "fueltech_id": "coal_black", "ts": "2025-10-06T15:30:00Z", "power": 149.8438, "emissions": 12.1848, "dispatch_type": "GENERATOR", "name": "Gladstone", "network_id": "NEM"}
# Published → facility/GSWF/GSWF1A: {"facility_code": "GSWF", "unit_code": "GSWF1A", "state": "SA", "lat": -33.682196, "lng": 138.936249, "fueltech_id": "wind", "ts": "2025-10-06T15:30:00Z", "power": 6.54, "emissions": 0.0, "dispatch_type": "GENERATOR", "name": "Goyder South", "network_id": "NEM"}
# Published → facility/GSWF/GSWF1B1: {"facility_code": "GSWF", "unit_code": "GSWF1B1", "state": "SA", "lat": -33.682196, "lng": 138.936249, "fueltech_id": "wind", "ts": "2025-10-06T15:30:00Z", "power": 0.75, "emissions": 0.0, "dispatch_type": "GENERATOR", "name": "Goyder South", "network_id": "NEM"}
# Published → facility/GULLRGWF/GULLRWF1: {"facility_code": "GULLRGWF", "unit_code": "GULLRWF1", "state": "NSW", "lat": -34.624512, "lng": 149.458549, "fueltech_id": "wind", "ts": "2025-10-06T15:30:00Z", "power": 8.4999, "emissions": 0.0, "dispatch_type": "GENERATOR", "name": "Gullen Range", "network_id": "NEM"}
# Published → facility/GUNNING/GUNNING1: {"facility_code": "GUNNING", "unit_code": "GUNNING1", "state": "NSW", "lat": -34.676361, "lng": 149.66443, "fueltech_id": "wind", "ts": "2025-10-06T15:30:00Z", "power": 2.1713, "emissions": 0.0, "dispatch_type": "GENERATOR", "name": "Gunning", "network_id": "NEM"}
# Published → facility/HBESS/HBESS1: {"facility_code": "HBESS", "unit_code": "HBESS1", "state": "VIC", "lat": -38.269216, "lng": 146.394724, "fueltech_id": "battery", "ts": "2025-10-06T15:30:00Z", "power": 0.8, "emissions": 0.0, "dispatch_type": "BIDIRECTIONAL", "name": "Hazelwood BESS", "network_id": "NEM"}
# Published → facility/HBESS/HBESSG1: {"facility_code": "HBESS", "unit_code": "HBESSG1", "state": "VIC", "lat": -38.269216, "lng": 146.394724, "fueltech_id": "battery_discharging", "ts": "2025-10-06T15:30:00Z", "power": 0.8, "emissions": 0.0, "dispatch_type": "GENERATOR", "name": "Hazelwood BESS", "network_id": "NEM"}
# Published → facility/HD1WF/HD1WF1: {"facility_code": "HD1WF", "unit_code": "HD1WF1", "state": "VIC", "lat": -38.148008, "lng": 142.360925, "fueltech_id": "wind", "ts": "2025-10-06T15:30:00Z", "power": 31.15, "emissions": 0.0, "dispatch_type": "GENERATOR", "name": "Hawkesdale", "network_id": "NEM"}
# Published → facility/HORNSDPR/HPR1: {"facility_code": "HORNSDPR", "unit_code": "HPR1", "state": "SA", "lat": -33.085519, "lng": 138.521914, "fueltech_id": "battery", "ts": "2025-10-06T15:30:00Z", "power": 1.1, "emissions": 0.0, "dispatch_type": "BIDIRECTIONAL", "name": "Hornsdale Power Reserve", "network_id": "NEM"}
# Published → facility/HORNSDPR/HPRG1: {"facility_code": "HORNSDPR", "unit_code": "HPRG1", "state": "SA", "lat": -33.085519, "lng": 138.521914, "fueltech_id": "battery_discharging", "ts": "2025-10-06T15:30:00Z", "power": 1.1, "emissions": 0.0, "dispatch_type": "GENERATOR", "name": "Hornsdale Power Reserve", "network_id": "NEM"}
# Published → facility/HVWW/HVWWBA1: {"facility_code": "HVWW", "unit_code": "HVWWBA1", "state": "SA", "lat": -35.063118, "lng": 138.56476, "fueltech_id": "battery", "ts": "2025-10-06T15:30:00Z", "power": 0.02, "emissions": 0.0, "dispatch_type": "BIDIRECTIONAL", "name": "Happy Valley", "network_id": "NEM"}
# Published → facility/HVWW/HVWWBA1G: {"facility_code": "HVWW", "unit_code": "HVWWBA1G", "state": "SA", "lat": -35.063118, "lng": 138.56476, "fueltech_id": "battery_discharging", "ts": "2025-10-06T15:30:00Z", "power": 0.02, "emissions": 0.0, "dispatch_type": "GENERATOR", "name": "Happy Valley", "network_id": "NEM"}
# Published → facility/JBUTTERS/JBUTTERS: {"facility_code": "JBUTTERS", "unit_code": "JBUTTERS", "state": "TAS", "lat": -42.15589, "lng": 145.536508, "fueltech_id": "hydro", "ts": "2025-10-06T15:30:00Z", "power": 143.8154, "emissions": 0.0, "dispatch_type": "GENERATOR", "name": "John Butters", "network_id": "NEM"}
# Published → facility/KABANWF/KABANWF1: {"facility_code": "KABANWF", "unit_code": "KABANWF1", "state": "QLD", "lat": -17.560606, "lng": 145.413125, "fueltech_id": "wind", "ts": "2025-10-06T15:30:00Z", "power": 27.67, "emissions": 0.0, "dispatch_type": "GENERATOR", "name": "Kaban", "network_id": "NEM"}
# Published → facility/KAREEYA/KAREEYA1: {"facility_code": "KAREEYA", "unit_code": "KAREEYA1", "state": "QLD", "lat": -17.766456, "lng": 145.576884, "fueltech_id": "hydro", "ts": "2025-10-06T15:30:00Z", "power": 21.6725, "emissions": 0.0, "dispatch_type": "GENERATOR", "name": "Kareeya", "network_id": "NEM"}
# Published → facility/KAREEYA/KAREEYA2: {"facility_code": "KAREEYA", "unit_code": "KAREEYA2", "state": "QLD", "lat": -17.766456, "lng": 145.576884, "fueltech_id": "hydro", "ts": "2025-10-06T15:30:00Z", "power": 21.59, "emissions": 0.0, "dispatch_type": "GENERATOR", "name": "Kareeya", "network_id": "NEM"}
# Published → facility/KAREEYA/KAREEYA3: {"facility_code": "KAREEYA", "unit_code": "KAREEYA3", "state": "QLD", "lat": -17.766456, "lng": 145.576884, "fueltech_id": "hydro", "ts": "2025-10-06T15:30:00Z", "power": 21.5275, "emissions": 0.0, "dispatch_type": "GENERATOR", "name": "Kareeya", "network_id": "NEM"}
# Published → facility/KAREEYA/KAREEYA4: {"facility_code": "KAREEYA", "unit_code": "KAREEYA4", "state": "QLD", "lat": -17.766456, "lng": 145.576884, "fueltech_id": "hydro", "ts": "2025-10-06T15:30:00Z", "power": 21.565, "emissions": 0.0, "dispatch_type": "GENERATOR", "name": "Kareeya", "network_id": "NEM"}
# Published → facility/KENNEDY/KEPWF1: {"facility_code": "KENNEDY", "unit_code": "KEPWF1", "state": "QLD", "lat": -20.872792, "lng": 144.413034, "fueltech_id": "wind", "ts": "2025-10-06T15:30:00Z", "power": 18.3, "emissions": 0.0, "dispatch_type": "GENERATOR", "name": "Kennedy Energy Park", "network_id": "NEM"}
# Published → facility/KESS1/KESSB1: {"facility_code": "KESS1", "unit_code": "KESSB1", "state": "VIC", "lat": -35.735367, "lng": 143.754813, "fueltech_id": "battery", "ts": "2025-10-06T15:30:00Z", "power": -1.07, "emissions": 0.0, "dispatch_type": "BIDIRECTIONAL", "name": "Koorangie", "network_id": "NEM"}
# Published → facility/KESS1/KESSL1: {"facility_code": "KESS1", "unit_code": "KESSL1", "state": "VIC", "lat": -35.735367, "lng": 143.754813, "fueltech_id": "battery_charging", "ts": "2025-10-06T15:30:00Z", "power": 1.07, "emissions": 0.0, "dispatch_type": "LOAD", "name": "Koorangie", "network_id": "NEM"}
# Published → facility/KIATAWF/KIATAWF1: {"facility_code": "KIATAWF", "unit_code": "KIATAWF1", "state": "VIC", "lat": -36.397693, "lng": 141.746827, "fueltech_id": "wind", "ts": "2025-10-06T15:30:00Z", "power": 3.8, "emissions": 0.0, "dispatch_type": "GENERATOR", "name": "Kiata", "network_id": "NEM"}
# Published → facility/KOGANCK/KPP_1: {"facility_code": "KOGANCK", "unit_code": "KPP_1", "state": "QLD", "lat": -26.915285, "lng": 150.748948, "fueltech_id": "coal_black", "ts": "2025-10-06T15:30:00Z", "power": 724.438, "emissions": 50.928, "dispatch_type": "GENERATOR", "name": "Kogan Creek", "network_id": "NEM"}
# Published → facility/LADBROKE/LADBROK1: {"facility_code": "LADBROKE", "unit_code": "LADBROK1", "state": "SA", "lat": -37.456183, "lng": 140.782699, "fueltech_id": "gas_ocgt", "ts": "2025-10-06T15:30:00Z", "power": 41.39, "emissions": 1.7515, "dispatch_type": "GENERATOR", "name": "Ladbroke Grove", "network_id": "NEM"}
# Published → facility/LADBROKE/LADBROK2: {"facility_code": "LADBROKE", "unit_code": "LADBROK2", "state": "SA", "lat": -37.456183, "lng": 140.782699, "fueltech_id": "gas_ocgt", "ts": "2025-10-06T15:30:00Z", "power": 42.13, "emissions": 1.7828, "dispatch_type": "GENERATOR", "name": "Ladbroke Grove", "network_id": "NEM"}
# Published → facility/LEM_WIL/LEM_WIL: {"facility_code": "LEM_WIL", "unit_code": "LEM_WIL", "state": "TAS", "lat": -41.483135, "lng": 146.125338, "fueltech_id": "hydro", "ts": "2025-10-06T15:30:00Z", "power": 86.8677, "emissions": 0.0, "dispatch_type": "GENERATOR", "name": "Lemonthyme / Wilmot", "network_id": "NEM"}
# Published → facility/LGAPWF1/LGAPWF1: {"facility_code": "LGAPWF1", "unit_code": "LGAPWF1", "state": "SA", "lat": -32.546333, "lng": 137.552763, "fueltech_id": "wind", "ts": "2025-10-06T15:30:00Z", "power": 8.29, "emissions": 0.0, "dispatch_type": "GENERATOR", "name": "Lincoln Gap", "network_id": "NEM"}
# Published → facility/LGAPWF1/LGAPWF2: {"facility_code": "LGAPWF1", "unit_code": "LGAPWF2", "state": "SA", "lat": -32.546333, "lng": 137.552763, "fueltech_id": "wind", "ts": "2025-10-06T15:30:00Z", "power": 7.05, "emissions": 0.0, "dispatch_type": "GENERATOR", "name": "Lincoln Gap", "network_id": "NEM"}
# Published → facility/LI_WY_CA/LI_WY_CA: {"facility_code": "LI_WY_CA", "unit_code": "LI_WY_CA", "state": "TAS", "lat": -42.376131, "lng": 146.509824, "fueltech_id": "hydro", "ts": "2025-10-06T15:30:00Z", "power": 87.8007, "emissions": 0.0, "dispatch_type": "GENERATOR", "name": "Catagunya / Liapootah / Wayatinah", "network_id": "NEM"}
# Published → facility/LKBONNY1/LKBONNY1: {"facility_code": "LKBONNY1", "unit_code": "LKBONNY1", "state": "SA", "lat": -37.760504, "lng": 140.405541, "fueltech_id": "wind", "ts": "2025-10-06T15:30:00Z", "power": 12.9499, "emissions": 0.0, "dispatch_type": "GENERATOR", "name": "Lake Bonney", "network_id": "NEM"}
# Published → facility/LKBONNY3/LKBONNY3: {"facility_code": "LKBONNY3", "unit_code": "LKBONNY3", "state": "SA", "lat": -37.760504, "lng": 140.405541, "fueltech_id": "wind", "ts": "2025-10-06T15:30:00Z", "power": 13.174, "emissions": 0.0, "dispatch_type": "GENERATOR", "name": "Lake Bonney 3", "network_id": "NEM"}
# Published → facility/LKBONNY_2/LKBONNY2: {"facility_code": "LKBONNY_2", "unit_code": "LKBONNY2", "state": "SA", "lat": -37.760504, "lng": 140.405541, "fueltech_id": "wind", "ts": "2025-10-06T15:30:00Z", "power": 34.4114, "emissions": 0.0, "dispatch_type": "GENERATOR", "name": "Lake Bonney 2", "network_id": "NEM"}
# Published → facility/LOYYANGA/LYA1: {"facility_code": "LOYYANGA", "unit_code": "LYA1", "state": "VIC", "lat": -38.250622, "lng": 146.576361, "fueltech_id": "coal_brown", "ts": "2025-10-06T15:30:00Z", "power": 560.0, "emissions": 54.1754, "dispatch_type": "GENERATOR", "name": "Loy Yang A", "network_id": "NEM"}
# Published → facility/LOYYANGA/LYA3: {"facility_code": "LOYYANGA", "unit_code": "LYA3", "state": "VIC", "lat": -38.250622, "lng": 146.576361, "fueltech_id": "coal_brown", "ts": "2025-10-06T15:30:00Z", "power": 560.0, "emissions": 54.1754, "dispatch_type": "GENERATOR", "name": "Loy Yang A", "network_id": "NEM"}
# Published → facility/LOYYANGA/LYA4: {"facility_code": "LOYYANGA", "unit_code": "LYA4", "state": "VIC", "lat": -38.250622, "lng": 146.576361, "fueltech_id": "coal_brown", "ts": "2025-10-06T15:30:00Z", "power": 561.0, "emissions": 54.2721, "dispatch_type": "GENERATOR", "name": "Loy Yang A", "network_id": "NEM"}
# Published → facility/LOYYB/LOYYB1: {"facility_code": "LOYYB", "unit_code": "LOYYB1", "state": "VIC", "lat": -38.253619, "lng": 146.585593, "fueltech_id": "coal_brown", "ts": "2025-10-06T15:30:00Z", "power": 578.25, "emissions": 54.0808, "dispatch_type": "GENERATOR", "name": "Loy Yang B", "network_id": "NEM"}
# Published → facility/LOYYB/LOYYB2: {"facility_code": "LOYYB", "unit_code": "LOYYB2", "state": "VIC", "lat": -38.253619, "lng": 146.585593, "fueltech_id": "coal_brown", "ts": "2025-10-06T15:30:00Z", "power": 580.5, "emissions": 54.2913, "dispatch_type": "GENERATOR", "name": "Loy Yang B", "network_id": "NEM"}
# Published → facility/LVES/LVES1: {"facility_code": "LVES", "unit_code": "LVES1", "state": "VIC", "lat": -38.258183, "lng": 146.418614, "fueltech_id": "battery", "ts": "2025-10-06T15:30:00Z", "power": -0.57, "emissions": 0.0, "dispatch_type": "BIDIRECTIONAL", "name": "Latrobe Valley", "network_id": "NEM"}
# Published → facility/LVES/LVESL1: {"facility_code": "LVES", "unit_code": "LVESL1", "state": "VIC", "lat": -38.258183, "lng": 146.418614, "fueltech_id": "battery_charging", "ts": "2025-10-06T15:30:00Z", "power": 0.57, "emissions": 0.0, "dispatch_type": "LOAD", "name": "Latrobe Valley", "network_id": "NEM"}
# Published → facility/MACARTH/MACARTH1: {"facility_code": "MACARTH", "unit_code": "MACARTH1", "state": "VIC", "lat": -38.043483, "lng": 142.179081, "fueltech_id": "wind", "ts": "2025-10-06T15:30:00Z", "power": 89.4, "emissions": 0.0, "dispatch_type": "GENERATOR", "name": "Macarthur", "network_id": "NEM"}
# Published → facility/MACKNTSH/MACKNTSH: {"facility_code": "MACKNTSH", "unit_code": "MACKNTSH", "state": "TAS", "lat": -41.701363, "lng": 145.646558, "fueltech_id": "hydro", "ts": "2025-10-06T15:30:00Z", "power": 88.13, "emissions": 0.0, "dispatch_type": "GENERATOR", "name": "Mackintosh", "network_id": "NEM"}
# Published → facility/MANNUMB/MANNUMB1: {"facility_code": "MANNUMB", "unit_code": "MANNUMB1", "state": "SA", "lat": -34.917537, "lng": 139.262695, "fueltech_id": "battery", "ts": "2025-10-06T15:30:00Z", "power": 0.45, "emissions": 0.0, "dispatch_type": "BIDIRECTIONAL", "name": "Mannum", "network_id": "NEM"}
# Published → facility/MANNUMB/MANNUMBG1: {"facility_code": "MANNUMB", "unit_code": "MANNUMBG1", "state": "SA", "lat": -34.917537, "lng": 139.262695, "fueltech_id": "battery_discharging", "ts": "2025-10-06T15:30:00Z", "power": 0.45, "emissions": 0.0, "dispatch_type": "GENERATOR", "name": "Mannum", "network_id": "NEM"}
# Published → facility/MBAHNTH/MBAHNTH: {"facility_code": "MBAHNTH", "unit_code": "MBAHNTH", "state": "QLD", "lat": -21.978481, "lng": 148.004809, "fueltech_id": "gas_wcmg", "ts": "2025-10-06T15:30:00Z", "power": 17.6, "emissions": 0.9355, "dispatch_type": "GENERATOR", "name": "Moranbah North", "network_id": "NEM"}
# Published → facility/MCINTYR/MCINTYR1: {"facility_code": "MCINTYR", "unit_code": "MCINTYR1", "state": "QLD", "lat": -28.2163, "lng": 152.0327, "fueltech_id": "wind", "ts": "2025-10-06T15:30:00Z", "power": 164.012, "emissions": 0.0, "dispatch_type": "GENERATOR", "name": "MacIntyre", "network_id": "NEM"}
# Published → facility/MCKAY/MCKAY1: {"facility_code": "MCKAY", "unit_code": "MCKAY1", "state": "VIC", "lat": -36.805471, "lng": 147.227845, "fueltech_id": "hydro", "ts": "2025-10-06T15:30:00Z", "power": 160.315, "emissions": 0.0, "dispatch_type": "GENERATOR", "name": "Bogong / Mackay", "network_id": "NEM"}
# Published → facility/MEADOWBK/MEADOWBK: {"facility_code": "MEADOWBK", "unit_code": "MEADOWBK", "state": "TAS", "lat": -42.610835, "lng": 146.846388, "fueltech_id": "hydro", "ts": "2025-10-06T15:30:00Z", "power": 41.4696, "emissions": 0.0, "dispatch_type": "GENERATOR", "name": "Meadowbank", "network_id": "NEM"}
# Published → facility/MEWF/MEWF1: {"facility_code": "MEWF", "unit_code": "MEWF1", "state": "QLD", "lat": -17.133248, "lng": 145.380037, "fueltech_id": "wind", "ts": "2025-10-06T15:30:00Z", "power": 86.4748, "emissions": 0.0, "dispatch_type": "GENERATOR", "name": "Mt Emerald", "network_id": "NEM"}
# Published → facility/MILLMERN/MPP_1: {"facility_code": "MILLMERN", "unit_code": "MPP_1", "state": "QLD", "lat": -27.961657, "lng": 151.28091, "fueltech_id": "coal_black", "ts": "2025-10-06T15:30:00Z", "power": 422.1028, "emissions": 29.4522, "dispatch_type": "GENERATOR", "name": "Millmerran", "network_id": "NEM"}
# Published → facility/MILLMERN/MPP_2: {"facility_code": "MILLMERN", "unit_code": "MPP_2", "state": "QLD", "lat": -27.961657, "lng": 151.28091, "fueltech_id": "coal_black", "ts": "2025-10-06T15:30:00Z", "power": 413.0998, "emissions": 28.8241, "dispatch_type": "GENERATOR", "name": "Millmerran", "network_id": "NEM"}
# Published → facility/MLWF/MLWF1: {"facility_code": "MLWF", "unit_code": "MLWF1", "state": "VIC", "lat": -37.833186, "lng": 142.465288, "fueltech_id": "wind", "ts": "2025-10-06T15:30:00Z", "power": 3.165, "emissions": 0.0, "dispatch_type": "GENERATOR", "name": "Mortons Lane", "network_id": "NEM"}
# Published → facility/MOORAWF1/MOORAWF1: {"facility_code": "MOORAWF1", "unit_code": "MOORAWF1", "state": "VIC", "lat": -37.739433, "lng": 144.171985, "fueltech_id": "wind", "ts": "2025-10-06T15:30:00Z", "power": 14.5, "emissions": 0.0, "dispatch_type": "GENERATOR", "name": "Moorabool", "network_id": "NEM"}
# Published → facility/MP/MP1: {"facility_code": "MP", "unit_code": "MP1", "state": "NSW", "lat": -33.360715, "lng": 150.035698, "fueltech_id": "coal_black", "ts": "2025-10-06T15:30:00Z", "power": 730.1015, "emissions": 52.8776, "dispatch_type": "GENERATOR", "name": "Mt Piper", "network_id": "NEM"}
# Published → facility/MP/MP2: {"facility_code": "MP", "unit_code": "MP2", "state": "NSW", "lat": -33.360715, "lng": 150.035698, "fueltech_id": "coal_black", "ts": "2025-10-06T15:30:00Z", "power": 699.8276, "emissions": 50.685, "dispatch_type": "GENERATOR", "name": "Mt Piper", "network_id": "NEM"}
# Published → facility/MRTLSWF/MRTLSWF1: {"facility_code": "MRTLSWF", "unit_code": "MRTLSWF1", "state": "VIC", "lat": -38.147965, "lng": 142.882246, "fueltech_id": "wind", "ts": "2025-10-06T15:30:00Z", "power": 55.03, "emissions": 0.0, "dispatch_type": "GENERATOR", "name": "Mortlake South", "network_id": "NEM"}
# Published → facility/MTGELWF/MTGELWF1: {"facility_code": "MTGELWF", "unit_code": "MTGELWF1", "state": "VIC", "lat": -38.257657, "lng": 143.798651, "fueltech_id": "wind", "ts": "2025-10-06T15:30:00Z", "power": 52.0035, "emissions": 0.0, "dispatch_type": "GENERATOR", "name": "Mt Gellibrand", "network_id": "NEM"}
# Published → facility/MTMERCER/MERCER01: {"facility_code": "MTMERCER", "unit_code": "MERCER01", "state": "VIC", "lat": -37.847593, "lng": 143.870183, "fueltech_id": "wind", "ts": "2025-10-06T15:30:00Z", "power": 16.5, "emissions": 0.0, "dispatch_type": "GENERATOR", "name": "Mt Mercer", "network_id": "NEM"}
# Published → facility/MTMILLAR/MTMILLAR: {"facility_code": "MTMILLAR", "unit_code": "MTMILLAR", "state": "SA", "lat": -33.619342, "lng": 136.717568, "fueltech_id": "wind", "ts": "2025-10-06T15:30:00Z", "power": 1.9, "emissions": 0.0, "dispatch_type": "GENERATOR", "name": "Mt Millar", "network_id": "NEM"}
# Published → facility/MURRAY/MURRAY: {"facility_code": "MURRAY", "unit_code": "MURRAY", "state": "VIC", "lat": -36.245992, "lng": 148.188552, "fueltech_id": "hydro", "ts": "2025-10-06T15:30:00Z", "power": 551.0, "emissions": 0.0, "dispatch_type": "GENERATOR", "name": "Murray", "network_id": "NEM"}
# Published → facility/MUSSELRO/MUSSELR1: {"facility_code": "MUSSELRO", "unit_code": "MUSSELR1", "state": "TAS", "lat": -40.777105, "lng": 148.006315, "fueltech_id": "wind", "ts": "2025-10-06T15:30:00Z", "power": 113.8, "emissions": 0.0, "dispatch_type": "GENERATOR", "name": "Musselroe", "network_id": "NEM"}
# Published → facility/MUWAWF/MUWAWF1: {"facility_code": "MUWAWF", "unit_code": "MUWAWF1", "state": "VIC", "lat": -36.438821, "lng": 142.246003, "fueltech_id": "wind", "ts": "2025-10-06T15:30:00Z", "power": 21.37, "emissions": 0.0, "dispatch_type": "GENERATOR", "name": "Murra Warra", "network_id": "NEM"}
# Published → facility/MUWAWF/MUWAWF2: {"facility_code": "MUWAWF", "unit_code": "MUWAWF2", "state": "VIC", "lat": -36.438821, "lng": 142.246003, "fueltech_id": "wind", "ts": "2025-10-06T15:30:00Z", "power": 21.0, "emissions": 0.0, "dispatch_type": "GENERATOR", "name": "Murra Warra", "network_id": "NEM"}
# Published → facility/NPPPPS/PPCCGT: {"facility_code": "NPPPPS", "unit_code": "PPCCGT", "state": "SA", "lat": -34.764365, "lng": 138.505399, "fueltech_id": "gas_ccgt", "ts": "2025-10-06T15:30:00Z", "power": 172.2099, "emissions": 5.7662, "dispatch_type": "GENERATOR", "name": "Pelican Point", "network_id": "NEM"}
# Published → facility/OAKLAND/OAKLAND1: {"facility_code": "OAKLAND", "unit_code": "OAKLAND1", "state": "VIC", "lat": -37.679481, "lng": 142.552995, "fueltech_id": "wind", "ts": "2025-10-06T15:30:00Z", "power": 7.2, "emissions": 0.0, "dispatch_type": "GENERATOR", "name": "Oaklands Hill", "network_id": "NEM"}
# Published → facility/OSBORNE/OSB-AG: {"facility_code": "OSBORNE", "unit_code": "OSB-AG", "state": "SA", "lat": -34.7977, "lng": 138.508099, "fueltech_id": "gas_ccgt", "ts": "2025-10-06T15:30:00Z", "power": 187.03, "emissions": 6.4588, "dispatch_type": "GENERATOR", "name": "Osborne", "network_id": "NEM"}
# Published → facility/PALOONA/PALOONA: {"facility_code": "PALOONA", "unit_code": "PALOONA", "state": "TAS", "lat": -41.28268, "lng": 146.24858, "fueltech_id": "hydro", "ts": "2025-10-06T15:30:00Z", "power": 14.73, "emissions": 0.0, "dispatch_type": "GENERATOR", "name": "Paloona", "network_id": "NEM"}
# Published → facility/PAREPW/PAREPW1: {"facility_code": "PAREPW", "unit_code": "PAREPW1", "state": "SA", "lat": -32.595609, "lng": 137.885629, "fueltech_id": "wind", "ts": "2025-10-06T15:30:00Z", "power": 25.15, "emissions": 0.0, "dispatch_type": "GENERATOR", "name": "Port Augusta Energy Park", "network_id": "NEM"}
# Published → facility/PIBESS/PIBESS1: {"facility_code": "PIBESS", "unit_code": "PIBESS1", "state": "VIC", "lat": -38.483293, "lng": 145.22488, "fueltech_id": "battery", "ts": "2025-10-06T15:30:00Z", "power": 0.0, "emissions": 0.0, "dispatch_type": "BIDIRECTIONAL", "name": "Phillip Island", "network_id": "NEM"}
# Published → facility/PIBESS/PIBESSG1: {"facility_code": "PIBESS", "unit_code": "PIBESSG1", "state": "VIC", "lat": -38.483293, "lng": 145.22488, "fueltech_id": "battery_discharging", "ts": "2025-10-06T15:30:00Z", "power": 0.0, "emissions": 0.0, "dispatch_type": "GENERATOR", "name": "Phillip Island", "network_id": "NEM"}
# Published → facility/PORTWF/PORTWF: {"facility_code": "PORTWF", "unit_code": "PORTWF", "state": "VIC", "lat": -38.361417, "lng": 141.38456, "fueltech_id": "wind", "ts": "2025-10-06T15:30:00Z", "power": 38.3, "emissions": 0.0, "dispatch_type": "GENERATOR", "name": "Portland", "network_id": "NEM"}
# Published → facility/PTINA/POAT220: {"facility_code": "PTINA", "unit_code": "POAT220", "state": "TAS", "lat": -41.805073, "lng": 146.924365, "fueltech_id": "hydro", "ts": "2025-10-06T15:30:00Z", "power": 11.66, "emissions": 0.0, "dispatch_type": "GENERATOR", "name": "Poatina", "network_id": "NEM"}
# Published → facility/RANGEB/RANGEB1: {"facility_code": "RANGEB", "unit_code": "RANGEB1", "state": "VIC", "lat": -38.0852, "lng": 145.259434, "fueltech_id": "battery", "ts": "2025-10-06T15:30:00Z", "power": -2.82, "emissions": 0.0, "dispatch_type": "BIDIRECTIONAL", "name": "Rangebank", "network_id": "NEM"}
# Published → facility/RANGEB/RANGEB1L1: {"facility_code": "RANGEB", "unit_code": "RANGEB1L1", "state": "VIC", "lat": -38.0852, "lng": 145.259434, "fueltech_id": "battery_charging", "ts": "2025-10-06T15:30:00Z", "power": 2.82, "emissions": 0.0, "dispatch_type": "LOAD", "name": "Rangebank", "network_id": "NEM"}
# Published → facility/REPULSE/REPULSE: {"facility_code": "REPULSE", "unit_code": "REPULSE", "state": "TAS", "lat": -42.507987, "lng": 146.64717, "fueltech_id": "hydro", "ts": "2025-10-06T15:30:00Z", "power": 3.1684, "emissions": 0.0, "dispatch_type": "GENERATOR", "name": "Repulse", "network_id": "NEM"}
# ...
# Published → facility/DPNTB/DPNTB1: {"facility_code": "DPNTB", "unit_code": "DPNTB1", "state": "NSW", "lat": -34.646668, "lng": 146.034982, "fueltech_id": "battery", "ts": "2025-10-06T17:25:00Z", "power": 0.0284, "emissions": 0.0, "dispatch_type": "BIDIRECTIONAL", "name": "Darlington Point", "network_id": "NEM"}
# Published → facility/DPNTB/DPNTBG1: {"facility_code": "DPNTB", "unit_code": "DPNTBG1", "state": "NSW", "lat": -34.646668, "lng": 146.034982, "fueltech_id": "battery_discharging", "ts": "2025-10-06T17:25:00Z", "power": 0.0284, "emissions": 0.0, "dispatch_type": "GENERATOR", "name": "Darlington Point", "network_id": "NEM"}
# Published → facility/DULAWF/DULAWF1: {"facility_code": "DULAWF", "unit_code": "DULAWF1", "state": "QLD", "lat": -26.637485, "lng": 149.870186, "fueltech_id": "wind", "ts": "2025-10-06T17:25:00Z", "power": 172.5, "emissions": 0.0, "dispatch_type": "GENERATOR", "name": "Dulacca", "network_id": "NEM"}
# Published → facility/DUNDWF/DUNDWF1: {"facility_code": "DUNDWF", "unit_code": "DUNDWF1", "state": "VIC", "lat": -37.863894, "lng": 142.943454, "fueltech_id": "wind", "ts": "2025-10-06T17:25:00Z", "power": 48.55, "emissions": 0.0, "dispatch_type": "GENERATOR", "name": "Dundonnell", "network_id": "NEM"}
# Published → facility/DUNDWF/DUNDWF2: {"facility_code": "DUNDWF", "unit_code": "DUNDWF2", "state": "VIC", "lat": -37.863894, "lng": 142.943454, "fueltech_id": "wind", "ts": "2025-10-06T17:25:00Z", "power": 12.66, "emissions": 0.0, "dispatch_type": "GENERATOR", "name": "Dundonnell", "network_id": "NEM"}
# Published → facility/DUNDWF/DUNDWF3: {"facility_code": "DUNDWF", "unit_code": "DUNDWF3", "state": "VIC", "lat": -37.863894, "lng": 142.943454, "fueltech_id": "wind", "ts": "2025-10-06T17:25:00Z", "power": 45.75, "emissions": 0.0, "dispatch_type": "GENERATOR", "name": "Dundonnell", "network_id": "NEM"}
# Published → facility/EILDON/EILDON1: {"facility_code": "EILDON", "unit_code": "EILDON1", "state": "VIC", "lat": -37.221262, "lng": 145.920966, "fueltech_id": "hydro", "ts": "2025-10-06T17:25:00Z", "power": 42.96, "emissions": 0.0, "dispatch_type": "GENERATOR", "name": "Eildon", "network_id": "NEM"}
# Published → facility/ELAINEWF/ELAINWF1: {"facility_code": "ELAINEWF", "unit_code": "ELAINWF1", "state": "VIC", "lat": -37.6352, "lng": 144.0237, "fueltech_id": "wind", "ts": "2025-10-06T17:25:00Z", "power": 20.96, "emissions": 0.0, "dispatch_type": "GENERATOR", "name": "Elaine", "network_id": "NEM"}
# Published → facility/ERARING/ER01: {"facility_code": "ERARING", "unit_code": "ER01", "state": "NSW", "lat": -33.061548, "lng": 151.524612, "fueltech_id": "coal_black", "ts": "2025-10-06T17:25:00Z", "power": 679.6857, "emissions": 50.5233, "dispatch_type": "GENERATOR", "name": "Eraring", "network_id": "NEM"}
# Published → facility/ERARING/ER02: {"facility_code": "ERARING", "unit_code": "ER02", "state": "NSW", "lat": -33.061548, "lng": 151.524612, "fueltech_id": "coal_black", "ts": "2025-10-06T17:25:00Z", "power": 685.2521, "emissions": 50.937, "dispatch_type": "GENERATOR", "name": "Eraring", "network_id": "NEM"}
# Published → facility/GANNBESS/GANNB1: {"facility_code": "GANNBESS", "unit_code": "GANNB1", "state": "VIC", "lat": -33.735056, "lng": 143.779462, "fueltech_id": "battery", "ts": "2025-10-06T17:25:00Z", "power": -0.0232, "emissions": 0.0, "dispatch_type": "BIDIRECTIONAL", "name": "Gannawarra", "network_id": "NEM"}
# Published → facility/GANNBESS/GANNBL1: {"facility_code": "GANNBESS", "unit_code": "GANNBL1", "state": "VIC", "lat": -33.735056, "lng": 143.779462, "fueltech_id": "battery_charging", "ts": "2025-10-06T17:25:00Z", "power": 0.0232, "emissions": 0.0, "dispatch_type": "LOAD", "name": "Gannawarra", "network_id": "NEM"}
# Published → facility/GERMCRK/GERMCRK: {"facility_code": "GERMCRK", "unit_code": "GERMCRK", "state": "QLD", "lat": -22.928526, "lng": 148.549097, "fueltech_id": "gas_wcmg", "ts": "2025-10-06T17:25:00Z", "power": 15.207, "emissions": 0.7169, "dispatch_type": "GENERATOR", "name": "German Creek", "network_id": "NEM"}
# Published → facility/GORDON/GORDON: {"facility_code": "GORDON", "unit_code": "GORDON", "state": "TAS", "lat": -42.740157, "lng": 145.983375, "fueltech_id": "hydro", "ts": "2025-10-06T17:25:00Z", "power": 23.7272, "emissions": 0.0, "dispatch_type": "GENERATOR", "name": "Gordon", "network_id": "NEM"}
# Published → facility/GPWFEST/GPWFEST1: {"facility_code": "GPWFEST", "unit_code": "GPWFEST1", "state": "VIC", "lat": -37.9729, "lng": 143.783, "fueltech_id": "wind", "ts": "2025-10-06T17:25:00Z", "power": 54.19, "emissions": 0.0, "dispatch_type": "GENERATOR", "name": "Golden Plains East", "network_id": "NEM"}
# Published → facility/GPWFEST/GPWFEST2: {"facility_code": "GPWFEST", "unit_code": "GPWFEST2", "state": "VIC", "lat": -37.9729, "lng": 143.783, "fueltech_id": "wind", "ts": "2025-10-06T17:25:00Z", "power": 36.34, "emissions": 0.0, "dispatch_type": "GENERATOR", "name": "Golden Plains East", "network_id": "NEM"}
# Published → facility/GPWFEST/GPWFEST3: {"facility_code": "GPWFEST", "unit_code": "GPWFEST3", "state": "VIC", "lat": -37.9729, "lng": 143.783, "fueltech_id": "wind", "ts": "2025-10-06T17:25:00Z", "power": 70.39, "emissions": 0.0, "dispatch_type": "GENERATOR", "name": "Golden Plains East", "network_id": "NEM"}
# Published → facility/GRANWF/GRANWF1: {"facility_code": "GRANWF", "unit_code": "GRANWF1", "state": "TAS", "lat": -41.802, "lng": 145.056, "fueltech_id": "wind", "ts": "2025-10-06T17:25:00Z", "power": 87.2, "emissions": 0.0, "dispatch_type": "GENERATOR", "name": "Granville Harbour", "network_id": "NEM"}
# Published → facility/GREENB/GREENB1: {"facility_code": "GREENB", "unit_code": "GREENB1", "state": "QLD", "lat": -27.733562, "lng": 152.955042, "fueltech_id": "battery", "ts": "2025-10-06T17:25:00Z", "power": -0.2801, "emissions": 0.0, "dispatch_type": "BIDIRECTIONAL", "name": "Greenbank", "network_id": "NEM"}
# Published → facility/GREENB/GREENB1L1: {"facility_code": "GREENB", "unit_code": "GREENB1L1", "state": "QLD", "lat": -27.733562, "lng": 152.955042, "fueltech_id": "battery_charging", "ts": "2025-10-06T17:25:00Z", "power": 0.2801, "emissions": 0.0, "dispatch_type": "LOAD", "name": "Greenbank", "network_id": "NEM"}
# Published → facility/GSTONE/GSTONE1: {"facility_code": "GSTONE", "unit_code": "GSTONE1", "state": "QLD", "lat": -23.848741, "lng": 151.220787, "fueltech_id": "coal_black", "ts": "2025-10-06T17:25:00Z", "power": 140.6426, "emissions": 11.4366, "dispatch_type": "GENERATOR", "name": "Gladstone", "network_id": "NEM"}
# Published → facility/GSTONE/GSTONE2: {"facility_code": "GSTONE", "unit_code": "GSTONE2", "state": "QLD", "lat": -23.848741, "lng": 151.220787, "fueltech_id": "coal_black", "ts": "2025-10-06T17:25:00Z", "power": 140.4033, "emissions": 11.4172, "dispatch_type": "GENERATOR", "name": "Gladstone", "network_id": "NEM"}
# Published → facility/GSTONE/GSTONE3: {"facility_code": "GSTONE", "unit_code": "GSTONE3", "state": "QLD", "lat": -23.848741, "lng": 151.220787, "fueltech_id": "coal_black", "ts": "2025-10-06T17:25:00Z", "power": 140.0205, "emissions": 11.386, "dispatch_type": "GENERATOR", "name": "Gladstone", "network_id": "NEM"}
# Published → facility/GSTONE/GSTONE4: {"facility_code": "GSTONE", "unit_code": "GSTONE4", "state": "QLD", "lat": -23.848741, "lng": 151.220787, "fueltech_id": "coal_black", "ts": "2025-10-06T17:25:00Z", "power": 140.3281, "emissions": 11.411, "dispatch_type": "GENERATOR", "name": "Gladstone", "network_id": "NEM"}
# Published → facility/GSTONE/GSTONE6: {"facility_code": "GSTONE", "unit_code": "GSTONE6", "state": "QLD", "lat": -23.848741, "lng": 151.220787, "fueltech_id": "coal_black", "ts": "2025-10-06T17:25:00Z", "power": 139.9863, "emissions": 11.3832, "dispatch_type": "GENERATOR", "name": "Gladstone", "network_id": "NEM"}
# Published → facility/GSWF/GSWF1A: {"facility_code": "GSWF", "unit_code": "GSWF1A", "state": "SA", "lat": -33.682196, "lng": 138.936249, "fueltech_id": "wind", "ts": "2025-10-06T17:25:00Z", "power": 2.28, "emissions": 0.0, "dispatch_type": "GENERATOR", "name": "Goyder South", "network_id": "NEM"}
# Published → facility/GSWF/GSWF1B1: {"facility_code": "GSWF", "unit_code": "GSWF1B1", "state": "SA", "lat": -33.682196, "lng": 138.936249, "fueltech_id": "wind", "ts": "2025-10-06T17:25:00Z", "power": 9.04, "emissions": 0.0, "dispatch_type": "GENERATOR", "name": "Goyder South", "network_id": "NEM"}
# Published → facility/GULLRGWF/GULLRWF1: {"facility_code": "GULLRGWF", "unit_code": "GULLRWF1", "state": "NSW", "lat": -34.624512, "lng": 149.458549, "fueltech_id": "wind", "ts": "2025-10-06T17:25:00Z", "power": 5.3649, "emissions": 0.0, "dispatch_type": "GENERATOR", "name": "Gullen Range", "network_id": "NEM"}
# Published → facility/HBESS/HBESS1: {"facility_code": "HBESS", "unit_code": "HBESS1", "state": "VIC", "lat": -38.269216, "lng": 146.394724, "fueltech_id": "battery", "ts": "2025-10-06T17:25:00Z", "power": -0.1, "emissions": 0.0, "dispatch_type": "BIDIRECTIONAL", "name": "Hazelwood BESS", "network_id": "NEM"}
# Published → facility/HD1WF/HD1WF1: {"facility_code": "HD1WF", "unit_code": "HD1WF1", "state": "VIC", "lat": -38.148008, "lng": 142.360925, "fueltech_id": "wind", "ts": "2025-10-06T17:25:00Z", "power": 35.37, "emissions": 0.0, "dispatch_type": "GENERATOR", "name": "Hawkesdale", "network_id": "NEM"}
# Published → facility/HORNSDAL3/HDWF3: {"facility_code": "HORNSDAL3", "unit_code": "HDWF3", "state": "SA", "lat": -33.05982, "lng": 138.537673, "fueltech_id": "wind", "ts": "2025-10-06T17:25:00Z", "power": 0.2, "emissions": 0.0, "dispatch_type": "GENERATOR", "name": "Hornsdale 3", "network_id": "NEM"}
# Published → facility/HORNSDPR/HPR1: {"facility_code": "HORNSDPR", "unit_code": "HPR1", "state": "SA", "lat": -33.085519, "lng": 138.521914, "fueltech_id": "battery", "ts": "2025-10-06T17:25:00Z", "power": 0.6, "emissions": 0.0, "dispatch_type": "BIDIRECTIONAL", "name": "Hornsdale Power Reserve", "network_id": "NEM"}
# Published → facility/HORNSDPR/HPRG1: {"facility_code": "HORNSDPR", "unit_code": "HPRG1", "state": "SA", "lat": -33.085519, "lng": 138.521914, "fueltech_id": "battery_discharging", "ts": "2025-10-06T17:25:00Z", "power": 0.6, "emissions": 0.0, "dispatch_type": "GENERATOR", "name": "Hornsdale Power Reserve", "network_id": "NEM"}
# Published → facility/HUMENSW/HUMENSW: {"facility_code": "HUMENSW", "unit_code": "HUMENSW", "state": "NSW", "lat": -36.106383, "lng": 147.032263, "fueltech_id": "hydro", "ts": "2025-10-06T17:25:00Z", "power": 20.7937, "emissions": 0.0, "dispatch_type": "GENERATOR", "name": "Hume", "network_id": "NEM"}
# Published → facility/HVWW/HVWWBA1: {"facility_code": "HVWW", "unit_code": "HVWWBA1", "state": "SA", "lat": -35.063118, "lng": 138.56476, "fueltech_id": "battery", "ts": "2025-10-06T17:25:00Z", "power": -0.004, "emissions": 0.0, "dispatch_type": "BIDIRECTIONAL", "name": "Happy Valley", "network_id": "NEM"}
# Published → facility/HVWW/HVWWBA1L: {"facility_code": "HVWW", "unit_code": "HVWWBA1L", "state": "SA", "lat": -35.063118, "lng": 138.56476, "fueltech_id": "battery_charging", "ts": "2025-10-06T17:25:00Z", "power": 0.004, "emissions": 0.0, "dispatch_type": "LOAD", "name": "Happy Valley", "network_id": "NEM"}
# Published → facility/JBUTTERS/JBUTTERS: {"facility_code": "JBUTTERS", "unit_code": "JBUTTERS", "state": "TAS", "lat": -42.15589, "lng": 145.536508, "fueltech_id": "hydro", "ts": "2025-10-06T17:25:00Z", "power": 144.1092, "emissions": 0.0, "dispatch_type": "GENERATOR", "name": "John Butters", "network_id": "NEM"}
# Published → facility/KABANWF/KABANWF1: {"facility_code": "KABANWF", "unit_code": "KABANWF1", "state": "QLD", "lat": -17.560606, "lng": 145.413125, "fueltech_id": "wind", "ts": "2025-10-06T17:25:00Z", "power": 70.141, "emissions": 0.0, "dispatch_type": "GENERATOR", "name": "Kaban", "network_id": "NEM"}
# Published → facility/KAREEYA/KAREEYA1: {"facility_code": "KAREEYA", "unit_code": "KAREEYA1", "state": "QLD", "lat": -17.766456, "lng": 145.576884, "fueltech_id": "hydro", "ts": "2025-10-06T17:25:00Z", "power": 21.59, "emissions": 0.0, "dispatch_type": "GENERATOR", "name": "Kareeya", "network_id": "NEM"}
# Published → facility/KAREEYA/KAREEYA2: {"facility_code": "KAREEYA", "unit_code": "KAREEYA2", "state": "QLD", "lat": -17.766456, "lng": 145.576884, "fueltech_id": "hydro", "ts": "2025-10-06T17:25:00Z", "power": 21.4875, "emissions": 0.0, "dispatch_type": "GENERATOR", "name": "Kareeya", "network_id": "NEM"}
# Published → facility/KAREEYA/KAREEYA3: {"facility_code": "KAREEYA", "unit_code": "KAREEYA3", "state": "QLD", "lat": -17.766456, "lng": 145.576884, "fueltech_id": "hydro", "ts": "2025-10-06T17:25:00Z", "power": 21.46, "emissions": 0.0, "dispatch_type": "GENERATOR", "name": "Kareeya", "network_id": "NEM"}
# Published → facility/KAREEYA/KAREEYA4: {"facility_code": "KAREEYA", "unit_code": "KAREEYA4", "state": "QLD", "lat": -17.766456, "lng": 145.576884, "fueltech_id": "hydro", "ts": "2025-10-06T17:25:00Z", "power": 21.485, "emissions": 0.0, "dispatch_type": "GENERATOR", "name": "Kareeya", "network_id": "NEM"}
# Published → facility/KESS1/KESSB1: {"facility_code": "KESS1", "unit_code": "KESSB1", "state": "VIC", "lat": -35.735367, "lng": 143.754813, "fueltech_id": "battery", "ts": "2025-10-06T17:25:00Z", "power": -1.09, "emissions": 0.0, "dispatch_type": "BIDIRECTIONAL", "name": "Koorangie", "network_id": "NEM"}
# Published → facility/KESS1/KESSL1: {"facility_code": "KESS1", "unit_code": "KESSL1", "state": "VIC", "lat": -35.735367, "lng": 143.754813, "fueltech_id": "battery_charging", "ts": "2025-10-06T17:25:00Z", "power": 1.09, "emissions": 0.0, "dispatch_type": "LOAD", "name": "Koorangie", "network_id": "NEM"}
# Published → facility/KIATAWF/KIATAWF1: {"facility_code": "KIATAWF", "unit_code": "KIATAWF1", "state": "VIC", "lat": -36.397693, "lng": 141.746827, "fueltech_id": "wind", "ts": "2025-10-06T17:25:00Z", "power": 6.1, "emissions": 0.0, "dispatch_type": "GENERATOR", "name": "Kiata", "network_id": "NEM"}
# Published → facility/KOGANCK/KPP_1: {"facility_code": "KOGANCK", "unit_code": "KPP_1", "state": "QLD", "lat": -26.915285, "lng": 150.748948, "fueltech_id": "coal_black", "ts": "2025-10-06T17:25:00Z", "power": 723.4477, "emissions": 50.8584, "dispatch_type": "GENERATOR", "name": "Kogan Creek", "network_id": "NEM"}
# Published → facility/LBBESS/LBB1: {"facility_code": "LBBESS", "unit_code": "LBB1", "state": "SA", "lat": -37.738787, "lng": 140.384672, "fueltech_id": "battery", "ts": "2025-10-06T17:25:00Z", "power": 0.0, "emissions": 0.0, "dispatch_type": "BIDIRECTIONAL", "name": "Lake Bonney", "network_id": "NEM"}
# Published → facility/LBBESS/LBBG1: {"facility_code": "LBBESS", "unit_code": "LBBG1", "state": "SA", "lat": -37.738787, "lng": 140.384672, "fueltech_id": "battery_discharging", "ts": "2025-10-06T17:25:00Z", "power": 0.0, "emissions": 0.0, "dispatch_type": "GENERATOR", "name": "Lake Bonney", "network_id": "NEM"}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-1494772015.py in <cell line: 0>()
#      55
#      56             info = client.publish(topic, payload, qos=PUBLISH_QOS, retain=RETAIN_LAST)
# ---> 57             info.wait_for_publish()
#      58             print(f"Published → {topic}: {payload}")
#      59
#
# /usr/local/lib/python3.12/dist-packages/paho/mqtt/client.py in wait_for_publish(self, timeout)
#     561         with self._condition:
#     562             while not self._published and not timed_out():
# --> 563                 self._condition.wait(timeout_tenth)
#     564
#     565         if self.rc > 0:
#
# /usr/lib/python3.12/threading.py in wait(self, timeout)
#     353         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     354             if timeout is None:
# --> 355                 waiter.acquire()
#     356                 gotit = True
#     357             else:
#
# KeyboardInterrupt:

# %% [markdown]
# Stop and disconnect for subsequent pulishing

# %%
client.loop_stop()
client.disconnect()
# Out:
# <MQTTErrorCode.MQTT_ERR_SUCCESS: 0>

# %% [markdown]
# # **Subscribing to topics**

# %% [markdown]
# Link to [Task 4](https://colab.research.google.com/drive/1po1VCTFsqmRZB_My2syF6yOzmx0wIMh5?usp=sharing)
